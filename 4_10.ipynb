# %% [markdown]
# <a href="https://colab.research.google.com/github/simjonghyeon04/-/blob/main/4_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager

# !pip install -q selenium
# !pip install -q webdriver_manager

# Install Chrome browser and its dependencies
# !apt-get update
# !wget -q -O - https://dl-ssl.google.com/linux/linux_signing_key.pub | apt-key add -
# !echo "deb http://dl.google.com/linux/chrome/deb/ stable main" >> /etc/apt/sources.list.d/google-chrome.list
# !apt-get update
# !apt-get install -y google-chrome-stable

options = webdriver.ChromeOptions()
options.add_argument("--headless=new")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

try:
    url = "https://comic.naver.com/webtoon"
    driver.get(url)

    wait = WebDriverWait(driver, 10)
    ul_selector = "#container > div.ListSpot__spot_wrap--Iko15 > div.content > div > ul"
    target_ul = wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, ul_selector)))

    items = target_ul.find_elements(By.TAG_NAME, "li")

    print("=== 실시간 신규 웹툰 3개 리포트 ===\n")

    for i, item in enumerate(items[:3], 1):
        lines = [line.strip() for line in item.text.split("\n") if line.strip()]
        lines = [line for line in lines if line != "신작"]

        if len(lines) >= 3:
            title = lines[0]
            author = lines[1]
            description = " ".join(lines[2:])
        elif len(lines) == 2:
            title = lines[0]
            author = lines[1]
            description = "내용 요약이 없습니다."
        else:
            continue

        print(f"[{i}번 웹툰]")
        print(f"제목 : {title}")
        print(f"작가 : {author}")
        print(f"내용 : {description}")
        print("-" * 40)

finally:
    time.sleep(2)
    driver.quit()
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:5 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Ign:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Ign:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Ign:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Ign:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Ign:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# ...
