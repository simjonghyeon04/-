# %% [markdown]
# <a href="https://colab.research.google.com/github/simjonghyeon04/-/blob/main/0320_02_class_initialize_attributes_method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<font color='blue'> Class = Chef**
# > ### **Understanding Class와 속성, 인스터스**

# %%
class Cheff:
    pass

# %% [markdown]
# - **Cheff** : without parentheses is a class definition.
# >> It defines a blueprint for creating objects. Cheff is **an empty class with no attributes or methods defined.** It's just a shell that can be used to create instances of the Cheff class.
#
# - **Cheff()**:
# >> Cheff() with parentheses is used **to create an instance (object) of the Cheff class**. When you call Cheff(), it creates a new object based on the blueprint defined by the Cheff class. This object can then be used to store data (attributes) and perform actions (methods) defined within the class.

# %%
Cheff
# Out:
# __main__.Cheff

# %%
__name__ == '__main__'
# Out:
# True

# %%
Cheff()

# %% [markdown]
# #### **함수와 다른 점**

# %%
def hello():
    print('Hi Hello')

# %%
hello
# Out:
# <function __main__.hello()>

# %%
hello()
# Out:
# Hi Hello

# %%
Cheff.id = '01'  # Cheff 클래스 자체에 새로운 클래스 속성을 추가

# %%
Cheff.id
# Out:
# '01'

# %%
Cheff.name = 'Tom'
Cheff.name
# Out:
# 'Tom'

# %%
Cheff
# Out:
# __main__.Cheff

# %%
# 인스턴스 생성
c1 = Cheff()
c2 = Cheff()

print(c1.name) # 출력: Tom
print(c2.name) # 출력: Tom
# Out:
# Tom
# Tom

# %% [markdown]
# ### **Class**
# >> **class Cheff:**
# >>> **pass**
#
# >> **user_1 = Cheff()**
#
# > ##### **1. 두 개의 객체가 생성**
# > ##### **2. Cheff라는 클라스이름은 클래스 객체를 바인딩(Binding)**
# > ##### **3. user_1 변수는 Cheff 클래스 타입의 객체를 바인딩**
# > ##### **<font color='blue'>4. 클래스와 객체가 각자 고유의 메모리 공간을 갖는다**
#
# - 클래스는 붕어빵틀(Cheff)로 객체(user_1)는 붕어빵틀로부터 구어진 붕어빵

# %%
class Cheff:
    pass

# %%
user_1 = Cheff()       # Class를 객체화

# %%
id(Cheff())
# Out:
# 133856959038224

# %%
id(Cheff)
# Out:
# 95464490414560

# %%
id(user_1)
# Out:
# 133856959044320

# %%
user_2 = Cheff()
id(user_2)
# Out:
# 133856959043552

# %% [markdown]
# **Why the Memory Addresses are Different:**
# - **Temporary Instance (id(Cheff())):**
# > Each call to Cheff() creates a new, unique instance of the Cheff class.
# When you call id(Cheff()), a new instance is created temporarily for the id function call, and this instance is not stored or referenced after the id call.
# Since it is a new instance, it has a unique memory address each time you call Cheff().
#
# - **Persistent Instance (id(user_1)):**
# > When you call user_1 = Cheff(), an instance of Cheff is created and stored in the variable user_1.
# The id(user_1) call retrieves the memory address of this specific, persistent instance.

# %%
# user_1 인스턴스에 새로운 인스턴스 속성을 추가
# user의 attributes 'id'를 생성하고 attributes의 값(vlaue)을 '001'이라고 함

user_1.id = '001'

# %%
user_1.username = 'tom'

# %%
user_1.marry = True

# %%
user_1.age = 25

# %%
print(user_1.id)
# Out:
# 001

# %%
print(user_1.username)
# Out:
# tom

# %%
print(user_1.age)
# Out:
# 25

# %%
print(user_1.marry)
# Out:
# True

# %% [markdown]
# 일반적으로는 클래스 내부에 변수를 미리 선언하지만, 파이썬에서는 클래스를 정의한 후에도 외부에서 마치 포스트잇을 붙이듯이 새로운 속성을 추가할 수 있습니다.
#
#
# 💡 주의할 점
# 실무에서는 이 방식보다는 __init__ 메서드를 사용해 객체를 만들 때 값을 넣어주는 방식을 권장합니다. 클래스 자체에 값을 고정해버리면 나중에 요리사마다 이름을 다르게 관리하기가 까다로워질 수 있거든요.
#
# 혹시 이 Cheff 클래스를 활용해 개별 요리사 객체마다 다른 아이디와 이름을 부여하는 코드로 발전시켜 볼까요? 원하신다면 __init__을 사용한 정석적인 코드를 만들어 봅시다.

# %% [markdown]
# #### **Chef를 쉽게 만드는 방법, 붕어빵 처럼 찍어내기**
# ### **<font color='blue'>Object = Tom, Mary, Henry, Magaret, Edward**
# <img src= 'https://img.freepik.com/free-vector/cook-collection-concept_23-2148514280.jpg?w=996&t=st=1690469366~exp=1690469966~hmac=1e8376fab19963197a896074cbd6f00d3f5a6e79360a9cd532bc4e5b6d6d8839' width = 700 height= 400>
#
#
# ## **<font color='blue'> chef = Chef(), object = Class()**
# ## **객체(chef)를 만들고 속성(attributes)과 메소드(method) 생성하기**

# %% [markdown]
# ## **1. 속성(attributes)**

# %% [markdown]
# - **user(cheff)가 수천 명이면 ?? 난감하네**
# ## Constructor
# ### Initialize(in·i·tial·ize/iˈniSHəˌlīz/) verb 가 필요
# #### COMPUTING
# - 1. set to the value or put in the condition appropriate to the start of an operation.
# "the counter is initialized to one"
# - 2. format (a computer disk).

# %% [markdown]
# > ### Constructor
# ---
# ### **class Car:**
# > **def __init __ (self):**
#
# >   - #### Initialize attributes
#
# <img src='https://pynative.com/wp-content/uploads/2021/07/create_declare_instance_variable.png'>
#
# >> ### **클래스에 속성을 추가하면 해당 클래스의 모든 인스턴스가 이 새로운 속성을 공유**
# >> ### **즉, id와 name 속성은 모든 Cheff 인스턴스에 적용**

# %%
class User:

# %%
class User:
    def __init__(self, user_id, user_name):
        self.id = user_id
        self.name = user_name

user_1 = User('001', 'Tom')
user_2 = User('002', 'Jerry')

# %%
# prompt: 100명의 user를 만들려면

users = []
for i in range(100):
  user_id = str(i).zfill(3)
  user_name = f"user_{i}"
  user = User(user_id, user_name)
  users.append(user)

# %%
users[1].id
# Out:
# '001'

# %%
', '.join([users[i].id for i in range(100)])
# Out:
# '000, 001, 002, 003, 004, 005, 006, 007, 008, 009, 010, 011, 012, 013, 014, 015, 016, 017, 018, 019, 020, 021, 022, 023, 024, 025, 026, 027, 028, 029, 030, 031, 032, 033, 034, 035, 036, 037, 038, 039, 040, 041, 042, 043, 044, 045, 046, 047, 048, 049, 050, 051, 052, 053, 054, 055, 056, 057, 058, 059, 060, 061, 062, 063, 064, 065, 066, 067, 068, 069, 070, 071, 072, 073, 074, 075, 076, 077, 078, 079, 080, 081, 082, 083, 084, 085, 086, 087, 088, 089, 090, 091, 092, 093, 094, 095, 096, 097, 098, 099'

# %%
', '.join([users[i].name for i in range(100)])
# Out:
# 'user_0, user_1, user_2, user_3, user_4, user_5, user_6, user_7, user_8, user_9, user_10, user_11, user_12, user_13, user_14, user_15, user_16, user_17, user_18, user_19, user_20, user_21, user_22, user_23, user_24, user_25, user_26, user_27, user_28, user_29, user_30, user_31, user_32, user_33, user_34, user_35, user_36, user_37, user_38, user_39, user_40, user_41, user_42, user_43, user_44, user_45, user_46, user_47, user_48, user_49, user_50, user_51, user_52, user_53, user_54, user_55, user_56, user_57, user_58, user_59, user_60, user_61, user_62, user_63, user_64, user_65, user_66, user_67, user_68, user_69, user_70, user_71, user_72, user_73, user_74, user_75, user_76, user_77, user_78, user_79, user_80, user_81, user_82, user_83, user_84, user_85, user_86, user_87, user_88, user_89, user_90, user_91, user_92, user_93, user_94, user_95, user_96, user_97, user_98, user_99'

# %%
user_1.id
# Out:
# '001'

# %%
user_2.name
# Out:
# 'Jerry'

# %%
class User:
    def __init__(self, user_id, user_name, user_age):
        self.id = user_id
        self.name = user_name
        self.age = user_age

user_1 = User('001', 'Tom', 35)
user_2 = User('002', 'Jerry', 33)

# %%
user_1.age
# Out:
# 35

# %% [markdown]
# ## **2. 메소드(method)**
#
# >> ### Cheff 대신 차량을 가정하여 Class를 만들어 보자
# ---
# ### **class Car:**
# > **def __init __ (self):**
# >   - ##### Initialize attributes (seats = 5)
# >   - **HAS (Attiributes)**
#
# > **def enter_race_mode():**
# >   - ##### chage attributes (seats = 1) for entering F1
# >   - **Does (Method, Change the attributes)**
#
#
# ---
#
# - car = Carbluprint()라면 자동차의 좌석수, 문짝 개수 등의 기본 속성을 정의
# - F1에 출전하려면 좌석을 1개로 줄여야 한다(method)
#
#
# <img src='https://media.istockphoto.com/id/1263896499/ko/%EC%82%AC%EC%A7%84/%EC%9D%BC%EB%AA%B0%EC%97%90-%EA%B7%B8%EB%9E%9C%EB%93%9C-%EC%8A%A4%ED%83%A0%EB%93%9C-%EA%B7%BC%EC%B2%98-%EA%B2%BD%EB%A7%88%EC%9E%A5%EC%97%90%EC%84%9C-%EB%B9%A0%EB%A5%B4%EA%B2%8C-%EC%9D%B4%EB%8F%99-%EA%B2%BD%EC%A3%BC-%EC%9E%90%EB%8F%99%EC%B0%A8.webp?b=1&s=170667a&w=0&k=20&c=Yi_YSedv8Cebb9AbZzFYaLEx0bzW4pYqzA2MD5yQHN0='>

# %%
class Car:
    # 1. 생성자: 객체가 만들어질 때 호출되는 함수
    def __init__(self, brand, model, color):
        self.brand = brand  # 브랜드
        self.model = model  # 모델명
        self.color = color  # 색상
        self.speed = 0      # 현재 속도 (기본값 0)

    # 2. 메서드: 자동차의 동작 (가속)
    def accelerate(self, amount):
        self.speed += amount
        print(f"{self.model}이(가) {amount}km/h 가속하여 현재 {self.speed}km/h입니다.")

    # 3. 메서드: 자동차의 동작 (정지)
    def stop(self):
        self.speed = 0
        print(f"{self.model}이(가) 멈췄습니다.")

# %%
# 'my_car'라는 실제 자동차 객체 생성
my_car = Car("Hyundai", "Ionic 6", "White")

# 'your_car'라는 또 다른 자동차 객체 생성
your_car = Car("Tesla", "Model 3", "Black")

# 각 자동차의 정보 출력
print(f"내 차는 {my_car.brand} {my_car.model}입니다.")
# 출력: 내 차는 Hyundai Ionic 6입니다.

# 자동차 동작시키기
my_car.accelerate(50)  # Ionic 6이 50km/h로 달립니다.
your_car.accelerate(80) # Model 3는 80km/h로 달립니다.
# Out:
# 내 차는 Hyundai Ionic 6입니다.
# Ionic 6이(가) 50km/h 가속하여 현재 50km/h입니다.
# Model 3이(가) 80km/h 가속하여 현재 80km/h입니다.

# %% [markdown]
# ## **과제 1. faker를 사용하여 1000명의 데이터를 class를 이용하여 만들어라**
#
# - [click faker](https://faker.readthedocs.io/en/master/)

# %% [markdown]
# ## **과제 2. Tom이 Jerry를 쫒아가는 행위를 method(함수)로 만들어 보자(10번 following)**
#
# ### **class User:**
# > **def __init __ (self):**
# >   - ##### Initialize attributes
# >   - **HAS (Attiributes)**
#
# > **def following_mode():**
# >   - ##### change attributes (following, follower) for chasing
# >   - **Does (Method, Change the attributes)**
#
# <img src= 'https://pbs.twimg.com/profile_images/810136393/tom-jerry-pic_400x400.jpg' width=300>

# %%
from faker import Faker

# 1. Faker 초기화 (한국어 설정)
fake = Faker('ko_KR')

# 2. 사용자 클래스 정의
class User:
    def __init__(self):
        self.name = fake.name()          # 이름
        self.email = fake.email()        # 이메일
        self.address = fake.address()    # 주소
        self.job = fake.job()            # 직업
        self.phone = fake.phone_number() # 전화번호

    def __repr__(self):
        return f"User(이름: {self.name}, 직업: {self.job})"

# 3. 1,000명의 데이터 생성
user_list = [User() for _ in range(1000)]

# 4. 결과 확인 (상위 5명만 출력)
print(f"총 생성된 데이터 수: {len(user_list)}명")
for user in user_list[:1000]:
    print(f"이름: {user.name} | 이메일: {user.email} | 직업: {user.job}")
# Out:
# 총 생성된 데이터 수: 1000명
# 이름: 김미영 | 이메일: vyun@example.org | 직업: 판금기 조작원
# 이름: 김승민 | 이메일: hyeonjunsin@example.com | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 김정순 | 이메일: pcoe@example.net | 직업: 건설 및 광업 관련 관리자
# 이름: 김미경 | 이메일: ei@example.com | 직업: 상품기획 전문가
# 이름: 김성민 | 이메일: gimsujin@example.org | 직업: 채소 및 특용작물 재배원
# 이름: 전현숙 | 이메일: gimsangceol@example.net | 직업: 자동차 정비원
# 이름: 김상훈 | 이메일: ihwang@example.org | 직업: 재활용 처리 및 소각로 조작원
# 이름: 최지원 | 이메일: sangceol89@example.net | 직업: 물리 및 작업 치료사
# 이름: 권춘자 | 이메일: seoyungim@example.com | 직업: 기타 주방장 및 조리사
# 이름: 박중수 | 이메일: jaeho29@example.net | 직업: 웹 개발자
# 이름: 조지은 | 이메일: dohyeonbag@example.net | 직업: 직업 운동선수
# 이름: 박보람 | 이메일: vgim@example.org | 직업: 기타 사육관련 종사원
# 이름: 박예준 | 이메일: geonubag@example.org | 직업: 자동차 조립원
# 이름: 박민서 | 이메일: seoyeongjin@example.net | 직업: 웹 개발자
# 이름: 장영순 | 이메일: areum08@example.org | 직업: 중식 주방장 및 조리사
# 이름: 이광수 | 이메일: seungmin02@example.net | 직업: 한식 주방장 및 조리사
# 이름: 김영수 | 이메일: jeongsugim@example.com | 직업: 위생사
# 이름: 양성훈 | 이메일: gweondonghyeon@example.org | 직업: 행사기획자
# 이름: 장동현 | 이메일: gyeongja78@example.org | 직업: 전자 부품 및 제품 제조 기계조작원
# 이름: 허정훈 | 이메일: jaehyeon18@example.com | 직업: 철로 설치 및 보수원
# 이름: 김민준 | 이메일: songseoyeon@example.com | 직업: 조명기사 및 영사기사
# 이름: 김성훈 | 이메일: ro@example.net | 직업: 음료 제조관련 기계 조작원
# 이름: 김미경 | 이메일: gyeonghyi35@example.org | 직업: 인사 및 노사 관련 전문가
# 이름: 이은경 | 이메일: seojun41@example.com | 직업: 조경원
# 이름: 권명숙 | 이메일: sanghun99@example.org | 직업: 기타 목재 및 종이 관련 기계조작원
# 이름: 배지아 | 이메일: eyun@example.net | 직업: 산업전공
# 이름: 서지혜 | 이메일: seongho45@example.net | 직업: 섬유공학 기술자 및 연구원
# 이름: 이서윤 | 이메일: jiyeweon@example.org | 직업: 보일러 설치 및 정비원
# 이름: 이성현 | 이메일: gimsunja@example.net | 직업: 대학 교육조교
# 이름: 장민수 | 이메일: yan@example.org | 직업: 마술사 및 기타 문화/ 예술 관련 종사자
# 이름: 안민준 | 이메일: donghyeon62@example.net | 직업: 보험 및 금융 상품 개발자
# 이름: 김예진 | 이메일: jgim@example.net | 직업: 회계 사무원
# 이름: 박미정 | 이메일: seongsu95@example.org | 직업: 패턴사
# 이름: 김성진 | 이메일: naogsun@example.net | 직업: 전자 부품 및 제품 제조 기계조작원
# 이름: 조상호 | 이메일: jia41@example.net | 직업: 가스/에너지 기술자 및 연구원
# 이름: 박승현 | 이메일: gimyunseo@example.com | 직업: 대학 시간강사
# 이름: 황준혁 | 이메일: xgim@example.com | 직업: 기타 문리/기술 및 예능 강사
# 이름: 임현지 | 이메일: yeonghwan41@example.org | 직업: 상점 판매원
# 이름: 이옥자 | 이메일: gweonhayun@example.org | 직업: 금속기계부품 조립원
# 이름: 김민준 | 이메일: seoseonghyeon@example.com | 직업: 가스/에너지 기술자 및 연구원
# 이름: 하정훈 | 이메일: kgim@example.net | 직업: 공업 배관공
# 이름: 최예원 | 이메일: caeungyeong@example.net | 직업: 농림어업관련 시험원
# 이름: 배미경 | 이메일: yejun44@example.com | 직업: 건설 및 광업 관련 관리자
# 이름: 장예준 | 이메일: simjeongsig@example.net | 직업: 도배공 및 유리 부착원
# 이름: 이하은 | 이메일: jiweon40@example.org | 직업: 유리제조 및 가공기 조작원
# 이름: 이숙자 | 이메일: eunjeong69@example.net | 직업: 산업안전 및 위험 관리원
# 이름: 박미경 | 이메일: bagjunhyeog@example.org | 직업: 기술 및 기능계 강사
# 이름: 이하은 | 이메일: yeji42@example.net | 직업: 운송관련 관리자
# 이름: 이승민 | 이메일: mijeong22@example.net | 직업: 법률관련 사무원
# 이름: 박순자 | 이메일: gweongwangsu@example.org | 직업: 선박 정비원
# 이름: 김동현 | 이메일: uo@example.net | 직업: 대학 교수
# 이름: 이예원 | 이메일: sinjeongsun@example.net | 직업: 콘크리트공
# 이름: 배영호 | 이메일: jongsu36@example.org | 직업: 상점 판매원
# 이름: 김윤서 | 이메일: qi@example.org | 직업: 기타 기능관련 종사원
# 이름: 김성훈 | 이메일: jeongsunjang@example.net | 직업: 경영 및 진단 전문가
# 이름: 정성현 | 이메일: hanjeongja@example.net | 직업: 미용사
# 이름: 최하윤 | 이메일: ogsunjo@example.org | 직업: 발전 및 배전장치 조작원
# 이름: 오미숙 | 이메일: gimhyeonjeong@example.net | 직업: 주방 보조원
# 이름: 안예진 | 이메일: areumgim@example.net | 직업: 전기 부품 및 제품제조 기계조작원
# 이름: 박현정 | 이메일: yeweon07@example.net | 직업: 경영 및 진단 전문가
# 이름: 이민석 | 이메일: nson@example.org | 직업: 택시 운전원
# 이름: 문영수 | 이메일: minji05@example.com | 직업: 여행상품 개발자
# 이름: 송숙자 | 이메일: cunja65@example.com | 직업: 섀시 조립 및 설치원
# 이름: 윤미경 | 이메일: junseo32@example.net | 직업: 상품기획 전문가
# 이름: 송민석 | 이메일: ui@example.com | 직업: 약사 및 한약사
# 이름: 김미경 | 이메일: sanghosong@example.net | 직업: 임상병리사
# 이름: 송서영 | 이메일: jeongungcoe@example.org | 직업: 바닥재 시공원
# 이름: 우서준 | 이메일: gimjeonghun@example.org | 직업: 지휘자/작곡가 및 연주가
# 이름: 이민지 | 이메일: hyeonsug64@example.com | 직업: 점토제품 생산기 조작원
# 이름: 박성호 | 이메일: qi@example.com | 직업: 장학관/연구관 및 교육 관련 전문가
# 이름: 김영희 | 이메일: baeyeonghwan@example.net | 직업: 기타 경호 및 보안 관련 종사원
# 이름: 민정자 | 이메일: bagmiyeong@example.org | 직업: 패턴사
# 이름: 이경숙 | 이메일: ancaeweon@example.com | 직업: 조세행정 사무원
# 이름: 이상호 | 이메일: gimcunja@example.net | 직업: 사회복지사
# 이름: 이지영 | 이메일: iseonghun@example.net | 직업: 변리사
# 이름: 김상훈 | 이메일: rgim@example.net | 직업: 철도 및 전동차 기관사
# 이름: 장영길 | 이메일: iseongho@example.net | 직업: 정부 및 공공 행정 전문가
# 이름: 남영숙 | 이메일: bagyeongsig@example.org | 직업: 기타 기술영업 및 중개 관련 종사자
# 이름: 진은영 | 이메일: gangminjae@example.com | 직업: 교육 관리자
# 이름: 손지후 | 이메일: baghyeonu@example.org | 직업: 제품 및 광고 영업원
# 이름: 이성훈 | 이메일: ugim@example.org | 직업: 장기 부사관 및 준위
# 이름: 김정호 | 이메일: eungyeong23@example.com | 직업: 성직자
# 이름: 이진우 | 이메일: gangjaehyeon@example.net | 직업: 우편물 집배원
# 이름: 이경자 | 이메일: subincoe@example.org | 직업: 전기/전자 및 기계 공학 시험원
# 이름: 이현준 | 이메일: gimjia@example.net | 직업: 운송장비 조립원
# 이름: 최선영 | 이메일: igyeongja@example.net | 직업: 무용가 및 안무가
# 이름: 이성민 | 이메일: coegyeonghyi@example.org | 직업: 법무사 및 집행관
# 이름: 배중수 | 이메일: sunjagang@example.org | 직업: 건축 도장공
# 이름: 문서영 | 이메일: gimhyeonju@example.net | 직업: 방문 판매원
# 이름: 나정수 | 이메일: yejungim@example.org | 직업: 전기/가스 및 수도 관련 관리자
# 이름: 김정수 | 이메일: sangho93@example.net | 직업: 한식 주방장 및 조리사
# 이름: 윤재호 | 이메일: yunseogweon@example.net | 직업: 산업안전 및 위험 관리원
# 이름: 박지은 | 이메일: yujinbag@example.net | 직업: 가구조립원
# 이름: 남채원 | 이메일: sjo@example.com | 직업: 자동차 영업원
# 이름: 노건우 | 이메일: subin04@example.org | 직업: 손해사정인
# 이름: 한준호 | 이메일: dohyeon37@example.net | 직업: 건설 및 광업 단순 종사원
# 이름: 이성훈 | 이메일: misugi@example.org | 직업: 플라스틱제품 생산기 조작원
# 이름: 김정수 | 이메일: isumin@example.com | 직업: 산업안전 및 위험 관리원
# 이름: 김하윤 | 이메일: eunseosong@example.org | 직업: 교육 관리자
# 이름: 박광수 | 이메일: sangceolhan@example.com | 직업: 도시 및 교통설계 전문가
# 이름: 황병철 | 이메일: jeongsiggim@example.org | 직업: 성직자
# 이름: 심지현 | 이메일: junseo27@example.org | 직업: 상품중개인 및 경매사
# 이름: 박영순 | 이메일: gimhayun@example.org | 직업: 인사 및 교육/훈련 사무원
# 이름: 박예지 | 이메일: vseo@example.org | 직업: 음향 및 녹음 기사
# 이름: 이건우 | 이메일: yejisim@example.com | 직업: 기타 기능관련 종사원
# 이름: 김성수 | 이메일: ibag@example.org | 직업: 보험 설계사 및 간접투자증권 판매인
# 이름: 김영순 | 이메일: zgim@example.org | 직업: 기타 사무원
# 이름: 조우진 | 이메일: jaehyeoni@example.net | 직업: 기타 배달원
# 이름: 이숙자 | 이메일: sgim@example.net | 직업: 광고 및 홍보 전문가
# 이름: 손병철 | 이메일: gimseohyeon@example.com | 직업: 검표원
# 이름: 오서현 | 이메일: jeonghobag@example.com | 직업: 물품이동 장비 조작원
# 이름: 홍영일 | 이메일: bagjeongsig@example.org | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 김현우 | 이메일: seohyeoni@example.net | 직업: 조경 기술자
# 이름: 최경수 | 이메일: qgim@example.com | 직업: 기타 기능관련 종사원
# 이름: 김예준 | 이메일: jeongsunbag@example.net | 직업: 금속 / 재료공학 연구원 및 기술자
# 이름: 박지은 | 이메일: hayun16@example.net | 직업: 작가 및 관련 전문가
# 이름: 김지혜 | 이메일: seohyeon47@example.net | 직업: 소방관
# 이름: 이영길 | 이메일: gimseonghyeon@example.com | 직업: 기타 전문서비스 관리자
# 이름: 장은영 | 이메일: gimjeongsun@example.org | 직업: 전문 의사
# 이름: 이하윤 | 이메일: aseo@example.com | 직업: 제빵원 및 제과원
# 이름: 이선영 | 이메일: gimseohyeon@example.org | 직업: 자동차 부분품 조립원
# 이름: 류서준 | 이메일: gjang@example.com | 직업: 방사선사
# 이름: 김동현 | 이메일: minjun23@example.com | 직업: 화학공학 시험원
# 이름: 김성호 | 이메일: yunyeweon@example.com | 직업: 기타 종교관련 종사자
# 이름: 권동현 | 이메일: kgu@example.net | 직업: 판금기 조작원
# 이름: 이영수 | 이메일: songmiyeong@example.net | 직업: 캐드원
# 이름: 이수빈 | 이메일: junseo80@example.org | 직업: 간호사
# 이름: 심은서 | 이메일: misugyu@example.org | 직업: 경기감독 및 코치
# 이름: 장종수 | 이메일: jiweon51@example.org | 직업: 판금원
# 이름: 문우진 | 이메일: wgim@example.com | 직업: 공업기계 설치 및 정비원
# 이름: 이정희 | 이메일: jangminji@example.net | 직업: 특수교육 교사
# 이름: 김하은 | 이메일: bagyeeun@example.com | 직업: 캐드원
# 이름: 강지영 | 이메일: hayuni@example.org | 직업: 단조원
# 이름: 김성호 | 이메일: dgweon@example.net | 직업: 응용 소프트웨어 개발자
# 이름: 김숙자 | 이메일: mgim@example.net | 직업: 종이제품 생산기 조작원
# 이름: 박춘자 | 이메일: seohyeon60@example.com | 직업: 영관급 이상
# 이름: 강진호 | 이메일: jihyeon03@example.net | 직업: 패턴사
# 이름: 이정호 | 이메일: yangjunyeong@example.com | 직업: 토목공학 기술자
# 이름: 이지우 | 이메일: gimcunja@example.org | 직업: 캐드원
# 이름: 이채원 | 이메일: man@example.org | 직업: 경량 철골공
# 이름: 이보람 | 이메일: sugjajo@example.org | 직업: 기술 영업원
# 이름: 이시우 | 이메일: donghyeon65@example.net | 직업: 통신 및 방송송출 장비 기사
# 이름: 이진우 | 이메일: yeweon44@example.net | 직업: 측량 및 지리정보 전문가
# 이름: 서경자 | 이메일: seonghoseo@example.net | 직업: 단조기 조작원
# 이름: 강은정 | 이메일: sujin73@example.com | 직업: 기타 기술영업 및 중개 관련 종사자
# 이름: 최병철 | 이메일: cgim@example.net | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 최민석 | 이메일: lbag@example.com | 직업: 시스템 소프트웨어 개발자
# 이름: 김옥자 | 이메일: eunjeonggim@example.com | 직업: 감정평가 전문가
# 이름: 이정희 | 이메일: jieunjeon@example.com | 직업: 외선전공
# 이름: 황지혜 | 이메일: bjo@example.com | 직업: 도장기 조작원
# 이름: 박혜진 | 이메일: jieuni@example.net | 직업: 승강기 설치 및 정비원
# 이름: 최승민 | 이메일: josugja@example.org | 직업: 보험 및 금융 관리자
# 이름: 조예지 | 이메일: ri@example.com | 직업: 치과위생사
# 이름: 이서윤 | 이메일: egim@example.org | 직업: 하역 및 적재 단순 종사원
# 이름: 송상현 | 이메일: igim@example.org | 직업: 배우 및 모델
# 이름: 김명숙 | 이메일: minseo77@example.org | 직업: 인쇄기 조작원
# 이름: 배준서 | 이메일: sanghyeongim@example.com | 직업: 방수공
# 이름: 김재호 | 이메일: egwag@example.org | 직업: 사회복지사
# 이름: 김옥자 | 이메일: yuyeeun@example.net | 직업: 공예원
# 이름: 김승현 | 이메일: yeongjagim@example.org | 직업: 가구조립원
# 이름: 박광수 | 이메일: yeongho40@example.org | 직업: 화물차 및 특수차 운전원
# 이름: 박예준 | 이메일: caeweon65@example.com | 직업: 기업고위임원
# 이름: 윤지원 | 이메일: seongsiu@example.net | 직업: 사회과학 연구원
# 이름: 이서준 | 이메일: seohyeonbag@example.net | 직업: 기타 이미용/예식 및 의료보조 서비스 종사원
# 이름: 오보람 | 이메일: fi@example.com | 직업: 양식원
# 이름: 김민재 | 이메일: minjaego@example.net | 직업: 투자 및 신용 분석가
# 이름: 윤지민 | 이메일: icoe@example.net | 직업: 물리 및 작업 치료사
# 이름: 이아름 | 이메일: jeongsig91@example.net | 직업: 보건위생 및 환경 검사원
# 이름: 홍혜진 | 이메일: qgim@example.com | 직업: 기타 배관공
# 이름: 민현준 | 이메일: gimyejin@example.org | 직업: 보험 설계사 및 간접투자증권 판매인
# 이름: 손동현 | 이메일: seungmin47@example.net | 직업: 화물차 및 특수차 운전원
# 이름: 이영환 | 이메일: yejinsong@example.com | 직업: 한의사
# 이름: 윤정숙 | 이메일: ujinyun@example.net | 직업: 과수작물 재배원
# 이름: 서민석 | 이메일: qgim@example.org | 직업: 대학 교수
# 이름: 송현우 | 이메일: gangyeongja@example.net | 직업: 항공기 객실승무원
# 이름: 김경자 | 이메일: seoyunbag@example.org | 직업: 보험 심사원 및 사무원
# 이름: 안미정 | 이메일: igyeongsug@example.org | 직업: 학습지 및 방문 교사
# 이름: 강현준 | 이메일: donghyeon90@example.net | 직업: 자동차 정비원
# 이름: 김정훈 | 이메일: hyeonsug54@example.org | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 윤정웅 | 이메일: hwangyeongil@example.net | 직업: 항공기 정비원
# 이름: 김숙자 | 이메일: hanogsun@example.net | 직업: 판금원
# 이름: 최미정 | 이메일: hanjia@example.net | 직업: 조경 기술자
# 이름: 서지우 | 이메일: jiyeon91@example.com | 직업: 패턴사
# 이름: 양현숙 | 이메일: seoyeonmun@example.org | 직업: 변호사
# 이름: 고은서 | 이메일: gyeongjabag@example.com | 직업: 큐레이터 및 문화재 보존원
# 이름: 류수민 | 이메일: cunja91@example.org | 직업: 정보 시스템 운영자
# 이름: 김지연 | 이메일: ieunji@example.com | 직업: 치과위생사
# 이름: 김성진 | 이메일: seoyeon67@example.net | 직업: 매표원 및 복권 판매원
# 이름: 김경수 | 이메일: mijeong80@example.com | 직업: 보육 교사
# 이름: 송성현 | 이메일: ogja91@example.net | 직업: 컴퓨터 보안 전문가
# 이름: 박승현 | 이메일: jeonghojang@example.org | 직업: 낙농업관련 종사원
# 이름: 강정훈 | 이메일: seonghyeonjo@example.org | 직업: 용접기 조작원
# 이름: 김예지 | 이메일: bi@example.com | 직업: 유리제조 및 가공기 조작원
# 이름: 이서준 | 이메일: jeonghyi14@example.net | 직업: 관세행정 사무원
# 이름: 김춘자 | 이메일: gimseunghyeon@example.com | 직업: 사회과학 연구원
# 이름: 김옥자 | 이메일: ki@example.net | 직업: 숙박/여행/오락 및 스포츠 관련 관리자
# 이름: 김상훈 | 이메일: isugja@example.net | 직업: 판금기 조작원
# 이름: 김성민 | 이메일: munjeonghun@example.com | 직업: 관세행정 사무원
# 이름: 민동현 | 이메일: oseo@example.com | 직업: 정육원 및 도축원
# 이름: 박지혜 | 이메일: jiweonbag@example.org | 직업: 기타 금융 및 보험 관련 전문가
# 이름: 허시우 | 이메일: yeongsug62@example.com | 직업: 보일러 설치 및 정비원
# 이름: 김시우 | 이메일: songyeongsug@example.net | 직업: 정육원 및 도축원
# 이름: 김순자 | 이메일: ucoe@example.com | 직업: 환경공학 시험원
# 이름: 최은영 | 이메일: ebag@example.org | 직업: 신발제조기 조작원 및 조립원
# 이름: 김수빈 | 이메일: jiyeon28@example.org | 직업: 청소원
# 이름: 김승민 | 이메일: jiu41@example.com | 직업: 상점 판매원
# 이름: 안영일 | 이메일: igim@example.org | 직업: 신용 추심원
# 이름: 백준호 | 이메일: jjang@example.net | 직업: 세탁관련 기계조작원
# 이름: 최경숙 | 이메일: munareum@example.org | 직업: 자산 운용가
# 이름: 배영환 | 이메일: coesugja@example.com | 직업: 화가 및 조각가
# 이름: 박지아 | 이메일: jangyeonggil@example.net | 직업: 증권 및 외환 딜러
# 이름: 김승현 | 이메일: gyeongsug81@example.com | 직업: 광석 및 석제품 가공기 조작원
# 이름: 박은경 | 이메일: zcoe@example.org | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 이준영 | 이메일: yunseo12@example.com | 직업: 인쇄기 조작원
# 이름: 송재현 | 이메일: hongjihye@example.org | 직업: 건설 및 광업 단순 종사원
# 이름: 이보람 | 이메일: doyuni@example.com | 직업: 계기 검침원 및 가스점검원
# 이름: 문현우 | 이메일: ni@example.net | 직업: 기타 직물 및 신발 관련 기계조작원 및 조립원
# 이름: 김준호 | 이메일: tgim@example.com | 직업: 응용 소프트웨어 개발자
# 이름: 박현우 | 이메일: yeongho65@example.org | 직업: 기타 문리/기술 및 예능 강사
# 이름: 장현우 | 이메일: cgim@example.org | 직업: 총무 사무원
# 이름: 허준영 | 이메일: juweon20@example.com | 직업: 기타 판매 및 고객 서비스 관리자
# 이름: 박중수 | 이메일: sanghunbag@example.com | 직업: 가구조립원
# 이름: 박준서 | 이메일: jimini@example.net | 직업: 관세행정 사무원
# 이름: 구정남 | 이메일: migyeong26@example.net | 직업: 금속기계부품 조립원
# 이름: 이광수 | 이메일: seohyeon44@example.org | 직업: 안내 / 접수 사무원 및 전화교환원
# 이름: 김미경 | 이메일: gbag@example.com | 직업: 통신/방송 및 인터넷 케이블 설치 및 수리원
# 이름: 이수빈 | 이메일: gimseonyeong@example.com | 직업: 교육 관리자
# 이름: 임민석 | 이메일: hwangjeongnam@example.org | 직업: 택시 운전원
# 이름: 김정식 | 이메일: ihyeonsug@example.org | 직업: 아나운서 및 리포터
# 이름: 이정웅 | 이메일: gyeonghyi68@example.org | 직업: 상품 대여원
# 이름: 이순자 | 이메일: gweoneunjeong@example.net | 직업: 보조 교사 및 기타 교사
# 이름: 임은영 | 이메일: gimminsu@example.com | 직업: 컴퓨터 보안 전문가
# 이름: 서정자 | 이메일: yejin73@example.net | 직업: 영관급 이상
# 이름: 박지현 | 이메일: dohyeonbag@example.com | 직업: 컴퓨터 강사
# 이름: 김건우 | 이메일: juweon33@example.org | 직업: 육아 도우미
# 이름: 김진호 | 이메일: yeongjin48@example.com | 직업: 구두 미화원
# 이름: 홍순자 | 이메일: rgim@example.com | 직업: 안내 / 접수 사무원 및 전화교환원
# 이름: 송정순 | 이메일: jeonghogim@example.org | 직업: 경량 철골공
# 이름: 신은영 | 이메일: baggwangsu@example.net | 직업: 도시 및 교통설계 전문가
# 이름: 권춘자 | 이메일: coehyeonjun@example.org | 직업: 관제사
# 이름: 이정자 | 이메일: jihyeon07@example.org | 직업: 모피 및 가죽의복 제조원
# 이름: 이지영 | 이메일: ei@example.com | 직업: 금형원
# 이름: 류정웅 | 이메일: gangjungsu@example.com | 직업: 마술사 및 기타 문화/ 예술 관련 종사자
# 이름: 김현지 | 이메일: fgim@example.com | 직업: 장례 상담원 및 장례 지도사
# 이름: 조영희 | 이메일: bagjieun@example.com | 직업: 상품기획 전문가
# 이름: 황지현 | 이메일: dgim@example.org | 직업: 소방공학 기술자 및 연구원
# 이름: 김수민 | 이메일: zhan@example.net | 직업: 타이어 및 고무제품 생산기 조작원
# 이름: 손성호 | 이메일: iogsun@example.net | 직업: 생명과학 연구원
# 이름: 박시우 | 이메일: seoyeon72@example.org | 직업: 세탁관련 기계조작원
# 이름: 류준혁 | 이메일: xgim@example.org | 직업: 플라스틱제품 생산기 조작원
# 이름: 류옥순 | 이메일: jeongja55@example.com | 직업: 숙박/여행/오락 및 스포츠 관련 관리자
# 이름: 김영수 | 이메일: heoseonyeong@example.com | 직업: 위생사
# 이름: 최승현 | 이메일: si@example.org | 직업: 정육원 및 도축원
# 이름: 백현숙 | 이메일: jinui@example.com | 직업: 기술 및 기능계 강사
# 이름: 김영호 | 이메일: dohyeonyun@example.org | 직업: 메이크업 아티스트 및 분장사
# 이름: 김미영 | 이메일: gimeunyeong@example.org | 직업: 기타 서비스관련 단순 종사원
# 이름: 김재호 | 이메일: gyeongsuggim@example.net | 직업: 영상/녹화 및 편집 기사
# 이름: 윤미숙 | 이메일: zgim@example.net | 직업: 항공기 조종사
# 이름: 류예준 | 이메일: donghyeonseo@example.com | 직업: 점토제품 생산기 조작원
# 이름: 박영숙 | 이메일: sumini@example.org | 직업: 도시 및 교통설계 전문가
# 이름: 최성훈 | 이메일: yeongceolgim@example.org | 직업: 매표원 및 복권 판매원
# 이름: 배재현 | 이메일: songgwangsu@example.com | 직업: 여행 사무원
# 이름: 김아름 | 이메일: seoyeongi@example.org | 직업: 장학관/연구관 및 교육 관련 전문가
# 이름: 김재호 | 이메일: junhyeoggim@example.net | 직업: 판금원
# 이름: 안성수 | 이메일: jeongsiggim@example.net | 직업: 화학물 가공장치 조작원
# 이름: 송승민 | 이메일: tjin@example.org | 직업: 고무 및 플라스틱 제품 조립원
# 이름: 김재현 | 이메일: jiuhong@example.net | 직업: 회계 사무원
# 이름: 김영환 | 이메일: misug41@example.net | 직업: 표백 및 염색 관련 조작원
# 이름: 허정자 | 이메일: yeongsug83@example.com | 직업: 재활용 처리 및 소각로 조작원
# 이름: 송미경 | 이메일: seoyun10@example.com | 직업: 컴퓨터 보안 전문가
# 이름: 오현준 | 이메일: yeonghyigim@example.org | 직업: 생명과학 연구원
# 이름: 김동현 | 이메일: ijunhyeog@example.org | 직업: 임산물채취 및 기타 임업 관련 종사원
# 이름: 서서연 | 이메일: byeongceoli@example.com | 직업: 하역 및 적재 단순 종사원
# 이름: 문민서 | 이메일: yejin58@example.net | 직업: 점토제품 생산기 조작원
# 이름: 김재현 | 이메일: seongjingim@example.net | 직업: 컴퓨터 강사
# 이름: 김영일 | 이메일: jaeho99@example.net | 직업: 광원/채석원 및 석재 절단원
# 이름: 박서준 | 이메일: donghyeon30@example.net | 직업: 의무기록사
# 이름: 김정훈 | 이메일: igyeongsu@example.org | 직업: 기타 경호 및 보안 관련 종사원
# 이름: 신준영 | 이메일: seoseungmin@example.net | 직업: 금형원
# 이름: 김예준 | 이메일: jeonghyi40@example.org | 직업: 바닥재 시공원
# 이름: 김동현 | 이메일: gbag@example.org | 직업: 원예작물 재배원
# 이름: 우성호 | 이메일: gimjihye@example.com | 직업: 음료 제조관련 기계 조작원
# 이름: 이영식 | 이메일: ngo@example.org | 직업: 사회복지사
# 이름: 한은영 | 이메일: sanghun77@example.org | 직업: 전기 부품 및 제품제조 기계조작원
# 이름: 안경자 | 이메일: kgim@example.com | 직업: 철도 및 전동차 기관사
# 이름: 이지원 | 이메일: igim@example.org | 직업: 화학공학 기술자 및 연구원
# 이름: 이도현 | 이메일: iyeongsun@example.com | 직업: 세무사
# 이름: 박재호 | 이메일: jeongmijeong@example.com | 직업: 환경 미화원 및 재활용품 수거원
# 이름: 김영진 | 이메일: sanghun18@example.com | 직업: 전산 자료 입력원 및 사무 보조원
# 이름: 김상현 | 이메일: yangseonghyeon@example.com | 직업: 정보 시스템 운영자
# 이름: 양정숙 | 이메일: gimminsu@example.com | 직업: 정부행정 관리자
# 이름: 윤예준 | 이메일: coeyeongsu@example.org | 직업: 안내 / 접수 사무원 및 전화교환원
# 이름: 박성훈 | 이메일: kan@example.com | 직업: 환경/청소 및 경비 관련 관리자
# 이름: 김현숙 | 이메일: yeongjin84@example.net | 직업: 타이어 및 고무제품 생산기 조작원
# 이름: 이은영 | 이메일: migyeonggim@example.org | 직업: 정보통신관련 관리자
# 이름: 황춘자 | 이메일: fgim@example.org | 직업: 소방관
# 이름: 백은주 | 이메일: seungminim@example.org | 직업: 화학공학 시험원
# 이름: 이혜진 | 이메일: zi@example.org | 직업: 항공기 객실승무원
# 이름: 손준호 | 이메일: seungminhan@example.com | 직업: 기술 및 기능계 강사
# 이름: 손정식 | 이메일: ijeonghun@example.net | 직업: 기타 행정 및 경영지원 관리자
# 이름: 최서윤 | 이메일: boram74@example.net | 직업: 택배원
# 이름: 김영자 | 이메일: hwanggyeongsu@example.net | 직업: 검표원
# 이름: 이영자 | 이메일: yunseohyeon@example.com | 직업: 통신/방송 및 인터넷 케이블 설치 및 수리원
# 이름: 이영철 | 이메일: gimyeongho@example.org | 직업: 기타 주방장 및 조리사
# 이름: 최상현 | 이메일: oan@example.org | 직업: 도금 및 금속분무기 조작원
# 이름: 김경수 | 이메일: jungsu15@example.org | 직업: 항공기 조종사
# 이름: 전영철 | 이메일: sinjuweon@example.org | 직업: 상담 전문가 및 청소년 지도사
# 이름: 박현숙 | 이메일: yeongmii@example.com | 직업: 학습지 및 방문 교사
# 이름: 김정호 | 이메일: jongsu01@example.net | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 김병철 | 이메일: hwangseungmin@example.net | 직업: 출납창구 사무원
# 이름: 최옥자 | 이메일: ogsunyang@example.org | 직업: 임상 심리사 및 기타 치료사
# 이름: 정수민 | 이메일: gyeongjagim@example.com | 직업: 세탁관련 기계조작원
# 이름: 홍정웅 | 이메일: jeongnami@example.net | 직업: 채소 및 특용작물 재배원
# 이름: 이은주 | 이메일: hyejinbag@example.org | 직업: 우편물 집배원
# 이름: 최영진 | 이메일: yeonghyibag@example.com | 직업: 운송관련 관리자
# 이름: 조재현 | 이메일: gweonminji@example.org | 직업: 기타 건설/전기 및 생산 관련 관리자
# 이름: 김시우 | 이메일: jbae@example.org | 직업: 가전제품 설치 및 수리원
# 이름: 김예은 | 이메일: gimsanghyeon@example.com | 직업: 관세행정 사무원
# 이름: 김현숙 | 이메일: byun@example.net | 직업: 소방관
# 이름: 박현정 | 이메일: yeongsun89@example.org | 직업: 섬유제조 기계조작원
# 이름: 손민재 | 이메일: qno@example.org | 직업: 학습지 및 방문 교사
# 이름: 이지후 | 이메일: jimin63@example.com | 직업: 외선전공
# 이름: 김정웅 | 이메일: iseongmin@example.com | 직업: 통신서비스판매원
# 이름: 박지아 | 이메일: isunja@example.org | 직업: 일반기계 조립원
# 이름: 황현주 | 이메일: byeongceol00@example.net | 직업: 금속 / 재료공학 시험원
# 이름: 권정호 | 이메일: hyeonu65@example.net | 직업: 선박 정비원
# 이름: 곽상호 | 이메일: anminsu@example.com | 직업: 금속기계부품 조립원
# 이름: 김미정 | 이메일: agim@example.org | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 이경자 | 이메일: gimogja@example.net | 직업: 공업 배관공
# 이름: 성영수 | 이메일: sumin89@example.org | 직업: 치과 의사
# 이름: 우지원 | 이메일: seoyeon08@example.org | 직업: 식품/섬유 공학 및 에너지 시험원
# 이름: 황지은 | 이메일: hanjunho@example.net | 직업: 건축 석공
# 이름: 최예지 | 이메일: jeongja75@example.com | 직업: 보험 설계사 및 간접투자증권 판매인
# 이름: 안민수 | 이메일: jihugim@example.net | 직업: 직조기 및 편직기 조작원
# 이름: 문옥순 | 이메일: pi@example.com | 직업: 인쇄기 조작원
# 이름: 황영숙 | 이메일: seonghyeon12@example.com | 직업: 간호조무사
# 이름: 김숙자 | 이메일: coeseojun@example.com | 직업: 위관급
# 이름: 박상호 | 이메일: seohyeon78@example.org | 직업: 기타 주방장 및 조리사
# 이름: 이경숙 | 이메일: iyeonghyi@example.org | 직업: 검표원
# 이름: 김종수 | 이메일: igim@example.com | 직업: 환경공학 시험원
# 이름: 강현정 | 이메일: imyeongsug@example.net | 직업: 기타 연극/영화 및 영상 관련 종사자
# 이름: 김준영 | 이메일: wi@example.net | 직업: 피부미용 및 체형관리사
# 이름: 이현주 | 이메일: sumin02@example.org | 직업: 대학 시간강사
# 이름: 안명자 | 이메일: oi@example.org | 직업: 소방공학 기술자 및 연구원
# 이름: 이옥순 | 이메일: doyuncoe@example.net | 직업: 정보 시스템 운영자
# 이름: 김민수 | 이메일: kgim@example.com | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 이영수 | 이메일: coeeunyeong@example.net | 직업: 공업 배관공
# 이름: 박영미 | 이메일: cunjabae@example.net | 직업: 타이어 및 고무제품 생산기 조작원
# 이름: 홍미숙 | 이메일: yeonghwanbag@example.org | 직업: 섀시 조립 및 설치원
# 이름: 이정순 | 이메일: junyeongju@example.com | 직업: 종이제품 생산기 조작원
# 이름: 황주원 | 이메일: seoyeong18@example.com | 직업: 전기/가스 및 수도 관련 관리자
# 이름: 권서윤 | 이메일: jiayun@example.org | 직업: 증권 및 외환 딜러
# 이름: 장정순 | 이메일: zjang@example.com | 직업: 제빵원 및 제과원
# 이름: 김정호 | 이메일: myeongsuggim@example.com | 직업: 산업안전 및 위험 관리원
# 이름: 이민수 | 이메일: than@example.org | 직업: 실내장식 디자이너
# 이름: 김중수 | 이메일: rno@example.org | 직업: 경기심판 및 경기기록원
# 이름: 윤준호 | 이메일: sangho21@example.org | 직업: 주차 관리원 및 안내원
# 이름: 김영철 | 이메일: fgim@example.net | 직업: 조림/영림 및 벌목원
# 이름: 박성현 | 이메일: gyeongsugbag@example.org | 직업: 제관원
# 이름: 김영호 | 이메일: junyeong01@example.com | 직업: 세무사
# 이름: 이정웅 | 이메일: hyeonsuggim@example.net | 직업: 장학관/연구관 및 교육 관련 전문가
# 이름: 김정자 | 이메일: ryuujin@example.org | 직업: 과실 및 채소 관련 기계조작원
# 이름: 문정훈 | 이메일: eungyeong28@example.net | 직업: 농림어업관련 단순 종사원
# 이름: 정영미 | 이메일: vi@example.com | 직업: 생명과학 연구원
# 이름: 이하윤 | 이메일: gimsangho@example.org | 직업: 생산 및 품질 관리 사무원
# 이름: 안현지 | 이메일: haeun39@example.org | 직업: 생산 및 품질 관리 사무원
# 이름: 한영일 | 이메일: fi@example.com | 직업: 공예원
# 이름: 이지연 | 이메일: sujin62@example.com | 직업: 기타 전기/전자기기 설치 및 수리원
# 이름: 이미경 | 이메일: rgim@example.com | 직업: 재단사
# 이름: 홍시우 | 이메일: hwangjeongja@example.com | 직업: 원예작물 재배원
# 이름: 박승민 | 이메일: gojeongung@example.com | 직업: 자동차 조립원
# 이름: 한민재 | 이메일: mijeong54@example.org | 직업: 기타 직물 및 신발 관련 기계조작원 및 조립원
# 이름: 조지연 | 이메일: jieuneom@example.com | 직업: 일식 주방장 및 조리사
# 이름: 김현우 | 이메일: sgim@example.net | 직업: 소년보호관 및 교도관
# 이름: 김지후 | 이메일: minji65@example.org | 직업: 구두 미화원
# 이름: 김성현 | 이메일: yeongjingim@example.net | 직업: 웹 개발자
# 이름: 장영철 | 이메일: minji43@example.com | 직업: 회계사
# 이름: 김민수 | 이메일: gyeongjagim@example.com | 직업: 대학 교육조교
# 이름: 조예준 | 이메일: yunseo30@example.net | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 우민재 | 이메일: isunog@example.net | 직업: 운송관련 관리자
# 이름: 한영수 | 이메일: sgim@example.org | 직업: 영상/녹화 및 편집 기사
# 이름: 김혜진 | 이메일: jgim@example.net | 직업: 영관급 이상
# 이름: 이민서 | 이메일: misuggim@example.net | 직업: 기타 사육관련 종사원
# 이름: 이현숙 | 이메일: ebae@example.org | 직업: 자연과학 시험원
# 이름: 이은서 | 이메일: jiu49@example.org | 직업: 화학물 가공장치 조작원
# 이름: 강숙자 | 이메일: oseo@example.net | 직업: 도배공 및 유리 부착원
# 이름: 안영희 | 이메일: hyeonjun53@example.org | 직업: 청원 경찰
# 이름: 이성진 | 이메일: isanghun@example.net | 직업: 건설 배관공
# 이름: 서준혁 | 이메일: bagjinho@example.com | 직업: 홍보 도우미 및 판촉원
# 이름: 구은정 | 이메일: jeongnamgim@example.net | 직업: 관제사
# 이름: 양영희 | 이메일: jcoe@example.org | 직업: 기타 음식서비스 종사원
# 이름: 장하윤 | 이메일: uno@example.com | 직업: 시멘트 및 광물제품 제조기 조작원
# 이름: 배성훈 | 이메일: jongsu91@example.org | 직업: 학습지 및 방문 교사
# 이름: 홍지후 | 이메일: areumi@example.org | 직업: 보육 교사
# 이름: 김지아 | 이메일: hyeonji69@example.org | 직업: 기타 주방장 및 조리사
# 이름: 윤옥순 | 이메일: rgim@example.net | 직업: 연구 관리자
# 이름: 이영철 | 이메일: igim@example.net | 직업: 촬영기사
# 이름: 박지혜 | 이메일: muneunji@example.net | 직업: 섬유공학 기술자 및 연구원
# 이름: 박상현 | 이메일: yeongsuno@example.org | 직업: 매표원 및 복권 판매원
# 이름: 노상호 | 이메일: jeongsigbag@example.net | 직업: 문화/예술/디자인 및 영상관련 관리자
# 이름: 이민재 | 이메일: myeongsug52@example.com | 직업: 기술 영업원
# 이름: 문지우 | 이메일: geonuan@example.org | 직업: 사회과학 연구원
# 이름: 박진호 | 이메일: kgang@example.net | 직업: 한식 주방장 및 조리사
# 이름: 박지은 | 이메일: hwangjunyeong@example.org | 직업: 석유 및 천연가스제조 관련 제어장치 조작원
# 이름: 박유진 | 이메일: sunjabag@example.net | 직업: 건축 목공
# 이름: 안정호 | 이메일: eunjeong83@example.com | 직업: 기타 사무원
# 이름: 이서현 | 이메일: gimsubin@example.org | 직업: 전기 및 전자 설비 조작원
# 이름: 오재현 | 이메일: ggim@example.net | 직업: 항공기 정비원
# 이름: 박하윤 | 이메일: namjongsu@example.net | 직업: 장학관/연구관 및 교육 관련 전문가
# 이름: 황지현 | 이메일: juweon86@example.org | 직업: 한의사
# 이름: 김정식 | 이메일: sumin34@example.org | 직업: 투자 및 신용 분석가
# 이름: 신우진 | 이메일: hwangjinho@example.org | 직업: 보험 및 금융 관리자
# 이름: 지지혜 | 이메일: gimjunyeong@example.org | 직업: 전문 의사
# 이름: 김영미 | 이메일: sjo@example.net | 직업: 상품 대여원
# 이름: 유영식 | 이메일: hyejini@example.com | 직업: 의지보조기기사
# 이름: 고영희 | 이메일: jongsujang@example.org | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 김수민 | 이메일: junho77@example.com | 직업: 육아 도우미
# 이름: 이은정 | 이메일: najinu@example.org | 직업: 악기제조 및 조율사
# 이름: 김준혁 | 이메일: bagjeongsu@example.com | 직업: 경량 철골공
# 이름: 문미경 | 이메일: jungsu46@example.net | 직업: 목재 가공관련 기계 조작원
# 이름: 박영호 | 이메일: coedoyun@example.org | 직업: 재단사
# 이름: 한영숙 | 이메일: gimmijeong@example.com | 직업: 과수작물 재배원
# 이름: 최영길 | 이메일: jeongsunhong@example.com | 직업: 가구조립원
# 이름: 김민준 | 이메일: gimjongsu@example.org | 직업: 통신/방송 및 인터넷 케이블 설치 및 수리원
# 이름: 황지현 | 이메일: jinu41@example.com | 직업: 제화원
# 이름: 김병철 | 이메일: qgim@example.org | 직업: 운송장비 조립원
# 이름: 송은영 | 이메일: ayun@example.net | 직업: 철로 설치 및 보수원
# 이름: 이영일 | 이메일: sangceoli@example.org | 직업: 숙박/여행/오락 및 스포츠 관련 관리자
# 이름: 김정호 | 이메일: hgim@example.org | 직업: 전기 및 전자 설비 조작원
# 이름: 하성훈 | 이메일: yeeun76@example.com | 직업: 화물열차 차장 및 관련 종사원
# 이름: 박은정 | 이메일: suminno@example.org | 직업: 건설 및 광업 관련 관리자
# 이름: 박주원 | 이메일: areumyun@example.com | 직업: 무용가 및 안무가
# 이름: 노도현 | 이메일: sanghyeongwag@example.net | 직업: 시각 디자이너
# 이름: 박정순 | 이메일: yeongjinsong@example.net | 직업: 웹 및 멀티미디어 디자이너
# 이름: 송영환 | 이메일: junhoson@example.net | 직업: 재봉사
# 이름: 류중수 | 이메일: gangmyeongsug@example.com | 직업: 보건의료관련 관리자
# 이름: 박윤서 | 이메일: jusangho@example.org | 직업: 기타 종교관련 종사자
# 이름: 김현지 | 이메일: jeongsiu@example.com | 직업: 가스/에너지 기술자 및 연구원
# 이름: 박미정 | 이메일: honggyeonghyi@example.net | 직업: 금속공작기계 조작원
# 이름: 송승현 | 이메일: hyeonjun94@example.net | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 오현준 | 이메일: sunog38@example.net | 직업: 고무 및 플라스틱 제품 조립원
# 이름: 임혜진 | 이메일: sgim@example.com | 직업: 운송관련 관리자
# 이름: 이예은 | 이메일: gimsubin@example.com | 직업: 웹 및 멀티미디어 기획자
# 이름: 이성민 | 이메일: pjeong@example.net | 직업: 장학관/연구관 및 교육 관련 전문가
# 이름: 장지민 | 이메일: lgim@example.net | 직업: 화학제품 생산기 조작원
# 이름: 송숙자 | 이메일: gyeongsugi@example.com | 직업: 금속 / 재료공학 시험원
# 이름: 구진우 | 이메일: yeongsugi@example.net | 직업: 귀금속 및 보석 세공원
# 이름: 오민석 | 이메일: vgim@example.com | 직업: 여행상품 개발자
# 이름: 김영일 | 이메일: hyeonuryu@example.com | 직업: 출판물 전문가
# 이름: 김정수 | 이메일: qi@example.org | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 오성수 | 이메일: sumin13@example.org | 직업: 기타 채굴 및 토목 관련 종사자
# 이름: 박순옥 | 이메일: gyeongsugim@example.net | 직업: 대학 교육조교
# 이름: 전성수 | 이메일: tno@example.net | 직업: 상품중개인 및 경매사
# 이름: 이수진 | 이메일: simminji@example.net | 직업: 석유 및 천연가스제조 관련 제어장치 조작원
# 이름: 임은영 | 이메일: areum23@example.net | 직업: 철도 기관차 및 전동차 정비원
# 이름: 윤성호 | 이메일: jinhocoe@example.org | 직업: 낙농업관련 종사원
# 이름: 이유진 | 이메일: jiai@example.com | 직업: 영상 및 관련 장비 설치 및 수리원
# 이름: 한지우 | 이메일: ii@example.org | 직업: 한복 제조원
# 이름: 이성민 | 이메일: sbag@example.net | 직업: 기타 기능관련 종사원
# 이름: 이재현 | 이메일: yunyejun@example.org | 직업: 공업 배관공
# 이름: 박경희 | 이메일: hanyeweon@example.org | 직업: 관제사
# 이름: 이영숙 | 이메일: imyeongsug@example.org | 직업: 신용 추심원
# 이름: 김민수 | 이메일: vgim@example.net | 직업: 응급구조사
# 이름: 박영철 | 이메일: ggim@example.net | 직업: 표백 및 염색 관련 조작원
# 이름: 이상현 | 이메일: jiyeon41@example.com | 직업: 기타 배관공
# 이름: 김준영 | 이메일: gyeongsubag@example.org | 직업: 기타 판매관련 단순 종사원
# 이름: 김서준 | 이메일: pgang@example.com | 직업: 검표원
# 이름: 이현주 | 이메일: yeongilhong@example.com | 직업: 양식원
# 이름: 송성호 | 이메일: donghyeonbag@example.net | 직업: 상품기획 전문가
# 이름: 백지아 | 이메일: jiagim@example.net | 직업: 해외 영업원
# 이름: 엄민서 | 이메일: minjun66@example.net | 직업: 냉동/냉장 /공조기 설치 및 정비원
# 이름: 백경수 | 이메일: dyu@example.org | 직업: 큐레이터 및 문화재 보존원
# 이름: 김수민 | 이메일: yyang@example.com | 직업: 기타 서비스관련 단순 종사원
# 이름: 강현우 | 이메일: yeongsuggim@example.com | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 김서연 | 이메일: iseongjin@example.org | 직업: 구두 미화원
# 이름: 이주원 | 이메일: gyeongjason@example.net | 직업: 지휘자/작곡가 및 연주가
# 이름: 조현우 | 이메일: hwangjinu@example.org | 직업: 상담 전문가 및 청소년 지도사
# 이름: 송영수 | 이메일: minjae53@example.net | 직업: 부동산 컨설턴트 및 중개인
# 이름: 나민석 | 이메일: boramgim@example.org | 직업: 도장기 조작원
# 이름: 박영진 | 이메일: zi@example.org | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 최지우 | 이메일: gimogsun@example.org | 직업: 기타 의복 제조원
# 이름: 김서영 | 이메일: jiyeong43@example.com | 직업: 신용 추심원
# 이름: 김영식 | 이메일: minseog31@example.net | 직업: 음식 배달원
# 이름: 김지은 | 이메일: sugja89@example.net | 직업: 목제품 제조관련 종사원
# 이름: 노수민 | 이메일: di@example.com | 직업: 조경원
# 이름: 황영수 | 이메일: juweon74@example.net | 직업: 경영 및 진단 전문가
# 이름: 서영호 | 이메일: hgim@example.net | 직업: 만화가 및 만화영화 작가
# 이름: 윤영길 | 이메일: sangho71@example.org | 직업: 주방 보조원
# 이름: 이미영 | 이메일: eunjeonghong@example.com | 직업: 판사 및 검사
# 이름: 박보람 | 이메일: xbag@example.org | 직업: 모피 및 가죽의복 제조원
# 이름: 이동현 | 이메일: ogja33@example.org | 직업: 기타 기술영업 및 중개 관련 종사자
# 이름: 김지현 | 이메일: seoyeong53@example.com | 직업: 조명기사 및 영사기사
# 이름: 성지현 | 이메일: gi@example.net | 직업: 운송 사무원
# 이름: 최은지 | 이메일: hyejin43@example.org | 직업: 인문과학 연구원
# 이름: 장영철 | 이메일: minjaeeom@example.com | 직업: 금속가공관련 제어장치 조작원
# 이름: 이정웅 | 이메일: minjungu@example.net | 직업: 일반 의사
# 이름: 이건우 | 이메일: hi@example.net | 직업: 식품/섬유 공학 및 에너지 시험원
# 이름: 이은영 | 이메일: minjungu@example.net | 직업: 방문 판매원
# 이름: 김미정 | 이메일: eunyeongyun@example.org | 직업: 숙박시설 서비스원
# 이름: 이하은 | 이메일: bageunji@example.com | 직업: 양식 주방장 및 조리사
# 이름: 박지원 | 이메일: miyeonggim@example.org | 직업: 배관 세정원 및 방역원
# 이름: 박민석 | 이메일: minjun29@example.org | 직업: 전자 부품 및 제품 제조 기계조작원
# 이름: 민영호 | 이메일: byun@example.org | 직업: 증권 및 외환 딜러
# 이름: 김지연 | 이메일: yejungim@example.net | 직업: 증권 및 외환 딜러
# 이름: 최예은 | 이메일: seojun83@example.net | 직업: 여행상품 개발자
# 이름: 조수민 | 이메일: cyang@example.com | 직업: 세탁원 및 다림질원
# 이름: 한정식 | 이메일: oi@example.net | 직업: 귀금속 및 보석 세공원
# 이름: 손광수 | 이메일: coeyeongsig@example.org | 직업: 화학공학 시험원
# 이름: 김지원 | 이메일: ybag@example.com | 직업: 컴퓨터 보안 전문가
# 이름: 이성진 | 이메일: hyeonji17@example.com | 직업: 인문과학 연구원
# 이름: 김정훈 | 이메일: jeongnam41@example.net | 직업: 종이제품 생산기 조작원
# 이름: 김종수 | 이메일: yunseocoe@example.com | 직업: 통신/방송 및 인터넷 케이블 설치 및 수리원
# 이름: 송영길 | 이메일: ijeong@example.com | 직업: 기타 사육관련 종사원
# 이름: 이승현 | 이메일: gangyeongil@example.com | 직업: 출판물 전문가
# 이름: 임옥자 | 이메일: kmun@example.org | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 이준영 | 이메일: seonghun27@example.net | 직업: 화가 및 조각가
# 이름: 하현우 | 이메일: gimogsun@example.net | 직업: 건축 목공
# 이름: 백상철 | 이메일: gimdoyun@example.com | 직업: 토목공학 기술자
# 이름: 최서준 | 이메일: jeongsun91@example.org | 직업: 전기 부품 및 제품제조 기계조작원
# 이름: 송지영 | 이메일: gangsumin@example.org | 직업: 사진인화 및 현상기 조작원
# 이름: 김정남 | 이메일: gimhaeun@example.org | 직업: 보험 및 금융 관리자
# 이름: 김준영 | 이메일: junhyeog12@example.com | 직업: 구두 미화원
# 이름: 김시우 | 이메일: yeongmisin@example.com | 직업: 상/하수도 처리장치 조작원
# 이름: 황미영 | 이메일: gimeunjeong@example.org | 직업: 증권 및 외환 딜러
# 이름: 한영길 | 이메일: hwangjieun@example.com | 직업: 행사기획자
# 이름: 김영수 | 이메일: seonghocoe@example.org | 직업: 채소 및 특용작물 재배원
# 이름: 이시우 | 이메일: rbag@example.net | 직업: 공업기계 설치 및 정비원
# 이름: 김서현 | 이메일: hyeonji50@example.org | 직업: 주조원
# 이름: 이상호 | 이메일: kcoe@example.net | 직업: 문리 및 어학 강사
# 이름: 김준호 | 이메일: qcoe@example.com | 직업: 상품중개인 및 경매사
# 이름: 이영수 | 이메일: eunjeongyang@example.org | 직업: 조림/영림 및 벌목원
# 이름: 김준혁 | 이메일: pgim@example.net | 직업: 상품중개인 및 경매사
# 이름: 이현주 | 이메일: gimhyeonju@example.org | 직업: 무인 경비원
# 이름: 김춘자 | 이메일: jjang@example.net | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 김민재 | 이메일: bagyeonghwan@example.org | 직업: 생명과학 시험원
# 이름: 조옥순 | 이메일: gwangsu98@example.com | 직업: 무용가 및 안무가
# 이름: 양민수 | 이메일: yeonghwango@example.org | 직업: 일반기계 조립원
# 이름: 나영희 | 이메일: minsusim@example.net | 직업: 섀시 조립 및 설치원
# 이름: 김정자 | 이메일: haeun04@example.org | 직업: 기술 및 기능계 강사
# 이름: 김은정 | 이메일: seoyeonggim@example.com | 직업: 건설 및 채굴 기계 운전원
# 이름: 이도현 | 이메일: gimjieun@example.org | 직업: 기타 운송장비 정비원
# 이름: 김수빈 | 이메일: byeongceolo@example.org | 직업: 플라스틱제품 생산기 조작원
# 이름: 이정수 | 이메일: coeyejun@example.net | 직업: 제품 생산관련 관리자
# 이름: 장은정 | 이메일: ni@example.net | 직업: 운송관련 관리자
# 이름: 이도현 | 이메일: mbag@example.net | 직업: 가축 사육 종사원
# 이름: 박준혁 | 이메일: yejini@example.net | 직업: 기타 운송장비 정비원
# 이름: 이승민 | 이메일: tgim@example.org | 직업: 컴퓨터 하드웨어 기술자 및 연구원
# 이름: 강수빈 | 이메일: hyejin71@example.org | 직업: 주조기 조작원
# 이름: 주영길 | 이메일: gimsugja@example.com | 직업: 무용가 및 안무가
# 이름: 한춘자 | 이메일: cajiyeon@example.com | 직업: 검표원
# 이름: 한영일 | 이메일: iryu@example.com | 직업: 철근공
# 이름: 김지우 | 이메일: yejun31@example.net | 직업: 웨이터
# 이름: 김성진 | 이메일: gyeongsug38@example.org | 직업: 변리사
# 이름: 홍준혁 | 이메일: hseo@example.net | 직업: 지휘자/작곡가 및 연주가
# 이름: 곽현지 | 이메일: ayun@example.org | 직업: 혼례 종사원
# 이름: 박지후 | 이메일: xsong@example.com | 직업: 식품 및 담배 등급원
# 이름: 송정남 | 이메일: gimhyeonu@example.net | 직업: 고객 상담 및 모니터 요원
# 이름: 허영순 | 이메일: misugi@example.net | 직업: 웹 및 멀티미디어 기획자
# 이름: 권도윤 | 이메일: bcoe@example.net | 직업: 주방 보조원
# 이름: 박상현 | 이메일: ihaeun@example.net | 직업: 예능 강사
# 이름: 김서영 | 이메일: myeongja56@example.net | 직업: 기타 주방장 및 조리사
# 이름: 최춘자 | 이메일: cajiu@example.org | 직업: 데이터베이스 개발자
# 이름: 김미영 | 이메일: namhyeonu@example.net | 직업: 수의사
# 이름: 백예지 | 이메일: ubag@example.com | 직업: 표백 및 염색 관련 조작원
# 이름: 박건우 | 이메일: lgim@example.com | 직업: 기타 여가 및 스포츠 관련 종사원
# 이름: 박준혁 | 이메일: doyungim@example.net | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 차서현 | 이메일: myun@example.com | 직업: 기자 및 논설위원
# 이름: 김영식 | 이메일: jujaeho@example.com | 직업: 회계 사무원
# 이름: 이시우 | 이메일: yeongmio@example.org | 직업: 안마사
# 이름: 이성수 | 이메일: jieun30@example.com | 직업: 예능 강사
# 이름: 손서연 | 이메일: gbae@example.org | 직업: 철로 설치 및 보수원
# 이름: 박영자 | 이메일: byang@example.org | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 류영식 | 이메일: jeonghyison@example.com | 직업: 경기감독 및 코치
# 이름: 이재호 | 이메일: hyeonju59@example.com | 직업: 웹 및 멀티미디어 기획자
# 이름: 박병철 | 이메일: ki@example.net | 직업: 제분 및 도정 관련 기계 조작원
# 이름: 김민석 | 이메일: cgim@example.com | 직업: 자연과학 연구원
# 이름: 장영길 | 이메일: bagjungsu@example.net | 직업: 기타 전기/전자기기 설치 및 수리원
# 이름: 윤현숙 | 이메일: jihye31@example.net | 직업: 건축 석공
# 이름: 김예은 | 이메일: vcoe@example.org | 직업: 생명과학 연구원
# 이름: 박성진 | 이메일: lhan@example.net | 직업: 택시 운전원
# 이름: 서유진 | 이메일: hyeonugim@example.net | 직업: 보육 교사
# 이름: 남영일 | 이메일: hyeonjubag@example.org | 직업: 가구조립원
# 이름: 문수빈 | 이메일: ngim@example.com | 직업: 재활용 처리 및 소각로 조작원
# 이름: 최성훈 | 이메일: kryu@example.net | 직업: 장례 상담원 및 장례 지도사
# 이름: 이지원 | 이메일: ujin70@example.org | 직업: 배관 세정원 및 방역원
# 이름: 김재현 | 이메일: mhwang@example.net | 직업: 택시 운전원
# 이름: 박미영 | 이메일: yeonghwan65@example.net | 직업: 큐레이터 및 문화재 보존원
# 이름: 오성민 | 이메일: obag@example.com | 직업: 점토제품 생산기 조작원
# 이름: 권아름 | 이메일: seunghyeonbag@example.com | 직업: 사서 및 기록물관리사
# 이름: 김준호 | 이메일: iyeongjin@example.com | 직업: 연구 관리자
# 이름: 김서현 | 이메일: kryu@example.org | 직업: 웹 개발자
# 이름: 최시우 | 이메일: eungyeonggang@example.org | 직업: 통역가
# 이름: 김아름 | 이메일: sangho13@example.org | 직업: 성직자
# 이름: 이현주 | 이메일: gyeongjagim@example.org | 직업: 기타 여가 및 스포츠 관련 종사원
# 이름: 배승현 | 이메일: gan@example.com | 직업: 변리사
# 이름: 장혜진 | 이메일: myeongsugi@example.org | 직업: 여행 및 관광통역 안내원
# 이름: 이민재 | 이메일: ggim@example.com | 직업: 일식 주방장 및 조리사
# 이름: 김숙자 | 이메일: yo@example.org | 직업: 변리사
# 이름: 강준영 | 이메일: gimsunog@example.com | 직업: 네트워크시스템 개발자
# 이름: 김도현 | 이메일: zyang@example.net | 직업: 정부행정 관리자
# 이름: 김지연 | 이메일: imsunog@example.net | 직업: 실내장식 디자이너
# 이름: 박아름 | 이메일: igim@example.net | 직업: 보험 심사원 및 사무원
# 이름: 이정웅 | 이메일: siu65@example.net | 직업: 물리 및 작업 치료사
# 이름: 김영진 | 이메일: ryusanghyeon@example.net | 직업: 과실 및 채소 관련 기계조작원
# 이름: 유은영 | 이메일: zbag@example.net | 직업: 어부 및 해녀
# 이름: 김준호 | 이메일: gimseongsu@example.net | 직업: 캐드원
# 이름: 김주원 | 이메일: bagjuweon@example.net | 직업: 보조 교사 및 기타 교사
# 이름: 김서준 | 이메일: jeonghuncoe@example.net | 직업: 통신 및 방송송출 장비 기사
# 이름: 문상호 | 이메일: vgim@example.com | 직업: 예능 강사
# 이름: 김영수 | 이메일: gimhyeonsug@example.com | 직업: 일반 의사
# 이름: 박도윤 | 이메일: munyeonghyi@example.org | 직업: 간호사
# 이름: 정재호 | 이메일: gimeunseo@example.org | 직업: 운송 사무원
# 이름: 서예준 | 이메일: seongjinsong@example.net | 직업: 노점 및 이동 판매원
# 이름: 이정자 | 이메일: jeongung08@example.org | 직업: 오락시설 서비스원
# 이름: 김성민 | 이메일: jeonghobag@example.com | 직업: 자재관리 사무원
# 이름: 김성현 | 이메일: jungsui@example.org | 직업: 육아 도우미
# 이름: 이예원 | 이메일: jeonghyi61@example.com | 직업: 경찰관
# 이름: 박정식 | 이메일: xgim@example.com | 직업: 건축 목공
# 이름: 심성수 | 이메일: siugim@example.com | 직업: 세탁관련 기계조작원
# 이름: 김은경 | 이메일: caeweon94@example.com | 직업: 고무 및 플라스틱 제품 조립원
# 이름: 권미정 | 이메일: seonghungim@example.org | 직업: 텔레마케터
# 이름: 김미정 | 이메일: jihu91@example.com | 직업: 건축 석공
# 이름: 전재호 | 이메일: jeongnam92@example.org | 직업: 기타 사회복지관련 종사원
# 이름: 김은경 | 이메일: junseoo@example.net | 직업: 과수작물 재배원
# 이름: 손건우 | 이메일: minseo76@example.org | 직업: 용접기 조작원
# 이름: 이상현 | 이메일: dhwang@example.org | 직업: 번역가
# 이름: 고미경 | 이메일: seongsu00@example.net | 직업: 문화/예술/디자인 및 영상관련 관리자
# 이름: 이성진 | 이메일: yeonggil70@example.net | 직업: 시스템 소프트웨어 개발자
# 이름: 이영자 | 이메일: djeon@example.org | 직업: 중/고등학교 교사
# 이름: 양민서 | 이메일: seoyeong13@example.org | 직업: 공업기계 설치 및 정비원
# 이름: 강승현 | 이메일: yeongsunyun@example.net | 직업: 비서
# 이름: 이진우 | 이메일: imyeongja@example.net | 직업: 금융관련 사무원
# 이름: 한현정 | 이메일: gimdonghyeon@example.net | 직업: 기타 서비스관련 단순 종사원
# 이름: 김정호 | 이메일: yeweon78@example.org | 직업: 제조관련 단순 종사원
# 이름: 우정웅 | 이메일: jiyeong11@example.net | 직업: 방문 판매원
# 이름: 김은경 | 이메일: jgim@example.org | 직업: 음료 제조관련 기계 조작원
# 이름: 박준영 | 이메일: ojang@example.net | 직업: 변리사
# 이름: 권은서 | 이메일: donghyeon15@example.org | 직업: 보험 및 금융 상품 개발자
# 이름: 장도현 | 이메일: areum85@example.com | 직업: 음식서비스관련 관리자
# 이름: 김종수 | 이메일: jeongjajang@example.net | 직업: 식품공학 기술자 및 연구원
# 이름: 이명숙 | 이메일: sbag@example.net | 직업: 대학 교육조교
# 이름: 하은영 | 이메일: hmun@example.com | 직업: 컴퓨터 하드웨어 기술자 및 연구원
# 이름: 고민준 | 이메일: jeonghyihwang@example.net | 직업: 관세행정 사무원
# 이름: 주은경 | 이메일: ujingim@example.net | 직업: 기타 음식서비스 종사원
# 이름: 김영철 | 이메일: ujini@example.net | 직업: 보건의료관련 관리자
# 이름: 이수빈 | 이메일: jiyeonnam@example.org | 직업: 치과위생사
# 이름: 홍도현 | 이메일: jeongsigi@example.net | 직업: 일반 의사
# 이름: 김지혜 | 이메일: ggim@example.com | 직업: 화학물 가공장치 조작원
# 이름: 최정식 | 이메일: seojungim@example.org | 직업: 기타 기술영업 및 중개 관련 종사자
# 이름: 김예준 | 이메일: hyeonju15@example.net | 직업: 우편물 집배원
# 이름: 박준영 | 이메일: migyeong93@example.com | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 김수민 | 이메일: gyeongsugim@example.org | 직업: 신용 추심원
# 이름: 백정수 | 이메일: hyeonjeong58@example.com | 직업: 금속공작기계 조작원
# 이름: 김수빈 | 이메일: sugja66@example.net | 직업: 기타 배달원
# 이름: 양서영 | 이메일: hyeonjucoe@example.net | 직업: 검표원
# 이름: 정예원 | 이메일: gyeongsu47@example.org | 직업: 항공기 정비원
# 이름: 이영호 | 이메일: seonghoi@example.net | 직업: 중/고등학교 교사
# 이름: 홍서준 | 이메일: gjeon@example.net | 직업: 정부행정 관리자
# 이름: 박미숙 | 이메일: jiminjeon@example.net | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 조현우 | 이메일: hcoe@example.com | 직업: 운송관련 관리자
# 이름: 박준영 | 이메일: hyejini@example.com | 직업: 양식 주방장 및 조리사
# 이름: 박영희 | 이메일: gimeunjeong@example.com | 직업: 화학공학 기술자 및 연구원
# 이름: 김승현 | 이메일: jiasim@example.org | 직업: 기타 배관공
# 이름: 최지우 | 이메일: yeongsugim@example.net | 직업: 상품 대여원
# 이름: 김정호 | 이메일: boram65@example.org | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 김유진 | 이메일: yeji22@example.com | 직업: 섬유제조 기계조작원
# 이름: 홍춘자 | 이메일: mgang@example.org | 직업: 혼례 종사원
# 이름: 홍성훈 | 이메일: sjo@example.org | 직업: 통신공학 기술자 및 연구원
# 이름: 김민준 | 이메일: seonghyeonyun@example.com | 직업: 통신공학 기술자 및 연구원
# 이름: 이준서 | 이메일: sgim@example.net | 직업: 재봉사
# 이름: 문명자 | 이메일: yejini@example.net | 직업: 악기제조 및 조율사
# 이름: 오은영 | 이메일: yeongceol70@example.com | 직업: 비파괴 검사원
# 이름: 김명자 | 이메일: dohyeoni@example.org | 직업: 통신서비스판매원
# 이름: 정경수 | 이메일: bi@example.com | 직업: 인쇄기 조작원
# 이름: 이옥자 | 이메일: yi@example.org | 직업: 문화/예술/디자인 및 영상관련 관리자
# 이름: 백민석 | 이메일: seongho99@example.net | 직업: 약사 및 한약사
# 이름: 박영숙 | 이메일: ji@example.net | 직업: 기타 식품가공관련 종사원
# 이름: 송영순 | 이메일: eyun@example.com | 직업: 항공기 조종사
# 이름: 김민수 | 이메일: yeongil58@example.com | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 이도현 | 이메일: bagsubin@example.com | 직업: 기타 행정 및 경영지원 관리자
# 이름: 박준호 | 이메일: gimogja@example.net | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 김서준 | 이메일: dgang@example.net | 직업: 음식서비스관련 관리자
# 이름: 김예지 | 이메일: ijuweon@example.org | 직업: 공업 배관공
# 이름: 이정식 | 이메일: minjicoe@example.net | 직업: 광원/채석원 및 석재 절단원
# 이름: 김경자 | 이메일: ajang@example.com | 직업: 큐레이터 및 문화재 보존원
# 이름: 최재호 | 이메일: iyeongsun@example.org | 직업: 전기/전자 부품 및 제품 조립원
# 이름: 김수민 | 이메일: tcoe@example.com | 직업: 육아 도우미
# 이름: 이승민 | 이메일: xcoe@example.net | 직업: 정부 및 공공 행정 전문가
# 이름: 차은지 | 이메일: siu97@example.com | 직업: 인쇄기 조작원
# 이름: 하준호 | 이메일: gimyeonggil@example.net | 직업: 대학 교육조교
# 이름: 강지영 | 이메일: xbaeg@example.com | 직업: 금융관련 사무원
# 이름: 김지혜 | 이메일: jaehoi@example.org | 직업: 사진기자 및 사진가
# 이름: 오우진 | 이메일: yundohyeon@example.org | 직업: 금속가공 기계조작원
# 이름: 박예은 | 이메일: zgo@example.net | 직업: 택시 운전원
# 이름: 최성훈 | 이메일: rgang@example.org | 직업: 상담 전문가 및 청소년 지도사
# 이름: 고승현 | 이메일: kgang@example.com | 직업: 만화가 및 만화영화 작가
# 이름: 김윤서 | 이메일: hyeonjujeong@example.com | 직업: 기타 배달원
# 이름: 이현정 | 이메일: seoyun04@example.net | 직업: 건설 및 광업 관련 관리자
# 이름: 김수빈 | 이메일: aryu@example.net | 직업: 산업안전 및 위험 관리원
# 이름: 배채원 | 이메일: ujang@example.org | 직업: 건설 배관공
# 이름: 강미숙 | 이메일: seunghyeon22@example.com | 직업: 일식 주방장 및 조리사
# 이름: 이광수 | 이메일: migyeong03@example.org | 직업: 초등학교 교사
# 이름: 한지영 | 이메일: ti@example.com | 직업: 귀금속 및 보석 세공원
# 이름: 장미숙 | 이메일: gimhyeonjeong@example.org | 직업: 기계공학 기술자 및 연구원
# 이름: 김현정 | 이메일: yeji72@example.com | 직업: 영업 및 판매 관련 관리자
# 이름: 홍정순 | 이메일: jeongung06@example.net | 직업: 기타 공학관련 기술자 및 시험원
# 이름: 이예지 | 이메일: yeweon54@example.org | 직업: 종이제품 생산기 조작원
# 이름: 강지혜 | 이메일: zcoe@example.org | 직업: 농림어업관련 시험원
# 이름: 양은영 | 이메일: ai@example.org | 직업: 화가 및 조각가
# 이름: 김지민 | 이메일: minsuyang@example.org | 직업: 금속가공관련 제어장치 조작원
# 이름: 김수빈 | 이메일: zgim@example.org | 직업: 제품 및 광고 영업원
# 이름: 노유진 | 이메일: zgim@example.com | 직업: 패턴사
# 이름: 황아름 | 이메일: yunyujin@example.com | 직업: 단열공
# 이름: 최혜진 | 이메일: yunseo92@example.net | 직업: 자동차 부분품 조립원
# 이름: 김현숙 | 이메일: bagjiweon@example.org | 직업: 매표원 및 복권 판매원
# 이름: 권보람 | 이메일: gimyejun@example.org | 직업: 광고 및 홍보 전문가
# 이름: 김건우 | 이메일: sanghun94@example.org | 직업: 해외 영업원
# 이름: 김영환 | 이메일: seoyeonjo@example.net | 직업: 회계 사무원
# 이름: 오영미 | 이메일: qgim@example.org | 직업: 보험 및 금융 상품 개발자
# 이름: 노정남 | 이메일: ijuweon@example.net | 직업: 사진인화 및 현상기 조작원
# 이름: 한채원 | 이메일: sangceoljang@example.net | 직업: 기타 이미용/예식 및 의료보조 서비스 종사원
# 이름: 이성훈 | 이메일: yeonghyi20@example.net | 직업: 김치 및 밑반찬 제조 종사원
# 이름: 김경숙 | 이메일: minsucoe@example.com | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 손현숙 | 이메일: hyeonjeong50@example.org | 직업: 생명과학 시험원
# 이름: 김지민 | 이메일: ijiyeon@example.org | 직업: 결혼 상담원 및 웨딩플래너
# 이름: 이혜진 | 이메일: eunju95@example.org | 직업: 큐레이터 및 문화재 보존원
# 이름: 최현주 | 이메일: jeongsug63@example.org | 직업: 대학 시간강사
# 이름: 김민지 | 이메일: jiyeon50@example.org | 직업: 방수공
# 이름: 양현지 | 이메일: bagyeongmi@example.net | 직업: 고무 및 플라스틱 제품 조립원
# 이름: 송서준 | 이메일: cunja23@example.com | 직업: 예능 강사
# 이름: 서중수 | 이메일: oeunseo@example.net | 직업: 제품 디자이너
# 이름: 남동현 | 이메일: yujin22@example.com | 직업: 임상병리사
# 이름: 최승민 | 이메일: hno@example.net | 직업: 장기 부사관 및 준위
# 이름: 허민지 | 이메일: yi@example.org | 직업: 증권 및 외환 딜러
# 이름: 하보람 | 이메일: junhyeogo@example.com | 직업: 임상 심리사 및 기타 치료사
# 이름: 노미정 | 이메일: yeeungim@example.com | 직업: 섀시 조립 및 설치원
# 이름: 한현지 | 이메일: jeonghobaeg@example.org | 직업: 실내장식 디자이너
# 이름: 김준영 | 이메일: gangjihye@example.com | 직업: 가전제품 설치 및 수리원
# 이름: 이지현 | 이메일: ei@example.net | 직업: 통역가
# 이름: 이도윤 | 이메일: geonu80@example.net | 직업: 간호조무사
# 이름: 김상철 | 이메일: gweonjiyeong@example.com | 직업: 자동차 부분품 조립원
# 이름: 윤성호 | 이메일: junhoi@example.com | 직업: 가수 및 성악가
# 이름: 박지현 | 이메일: egim@example.net | 직업: 회계 사무원
# 이름: 이예준 | 이메일: ycoe@example.com | 직업: 종이제품 생산기 조작원
# 이름: 권명자 | 이메일: jinhoyun@example.com | 직업: 건축 석공
# 이름: 이현정 | 이메일: gimjeonghyi@example.com | 직업: 장학관/연구관 및 교육 관련 전문가
# 이름: 이미영 | 이메일: jongsuan@example.org | 직업: 응용 소프트웨어 개발자
# 이름: 남지혜 | 이메일: minjun90@example.org | 직업: 낙농업관련 종사원
# 이름: 류지우 | 이메일: junseojang@example.net | 직업: 통신공학 기술자 및 연구원
# 이름: 양성현 | 이메일: yeongsug15@example.org | 직업: 치과 의사
# 이름: 김승민 | 이메일: xhan@example.org | 직업: 기타 배관공
# 이름: 전성진 | 이메일: sunjagang@example.com | 직업: 운송 사무원
# 이름: 김영숙 | 이메일: juweon68@example.net | 직업: 자연과학 시험원
# 이름: 박옥자 | 이메일: gyeongsu51@example.org | 직업: 인사 및 노사 관련 전문가
# 이름: 최우진 | 이메일: iyeweon@example.org | 직업: 변리사
# 이름: 이영수 | 이메일: vgim@example.net | 직업: 문리 및 어학 강사
# 이름: 이영자 | 이메일: gimmyeongja@example.org | 직업: 응용 소프트웨어 개발자
# 이름: 윤보람 | 이메일: mbag@example.org | 직업: 과실 및 채소 관련 기계조작원
# 이름: 황명숙 | 이메일: gyeongja35@example.net | 직업: 도금 및 금속분무기 조작원
# 이름: 한선영 | 이메일: minseogim@example.org | 직업: 경영지원 관리자
# 이름: 장정순 | 이메일: hryu@example.net | 직업: 컴퓨터시스템 설계 및 분석가
# 이름: 권영식 | 이메일: qhwang@example.net | 직업: 제관기 조작원
# 이름: 이영철 | 이메일: wo@example.com | 직업: 소방관
# 이름: 김광수 | 이메일: xgim@example.com | 직업: 기타 여가 및 스포츠 관련 종사원
# 이름: 김영식 | 이메일: munjihye@example.org | 직업: 대학 시간강사
# 이름: 강정남 | 이메일: tbag@example.org | 직업: 웨이터
# 이름: 이예진 | 이메일: hyeonsugu@example.org | 직업: 건설자재 시험원
# 이름: 박준혁 | 이메일: areum80@example.net | 직업: 배우 및 모델
# 이름: 이은정 | 이메일: jeongsun88@example.com | 직업: 보건위생 및 환경 검사원
# 이름: 유승민 | 이메일: gbag@example.org | 직업: 기타 건설관련 기능 종사원
# 이름: 안정수 | 이메일: hyeonjuni@example.com | 직업: 떡제조원
# 이름: 홍성진 | 이메일: gimsujin@example.org | 직업: 기술 및 기능계 강사
# 이름: 김영미 | 이메일: minseogim@example.net | 직업: 통신서비스판매원
# 이름: 조옥자 | 이메일: jeonghosong@example.net | 직업: 중/고등학교 교사
# 이름: 박준호 | 이메일: iseonghyeon@example.net | 직업: 기타 연극/영화 및 영상 관련 종사자
# 이름: 이은주 | 이메일: minseog05@example.com | 직업: 석유 및 천연가스제조 관련 제어장치 조작원
# 이름: 홍성현 | 이메일: eunjeonggim@example.net | 직업: 메이크업 아티스트 및 분장사
# 이름: 이하은 | 이메일: pryu@example.net | 직업: 제관원
# 이름: 김예지 | 이메일: idohyeon@example.com | 직업: 상품중개인 및 경매사
# 이름: 황지현 | 이메일: vgim@example.org | 직업: 철로 설치 및 보수원
# 이름: 주현지 | 이메일: yi@example.org | 직업: 출납창구 사무원
# 이름: 한도현 | 이메일: iyeongil@example.net | 직업: 직업 운동선수
# 이름: 김재현 | 이메일: zcoe@example.org | 직업: 고객 상담 및 모니터 요원
# 이름: 장서영 | 이메일: fcoe@example.net | 직업: 경영지원 관리자
# 이름: 이유진 | 이메일: jangsanghun@example.net | 직업: 치과 의사
# 이름: 우춘자 | 이메일: jeonghunbag@example.com | 직업: 영양사
# 이름: 문도윤 | 이메일: jihye32@example.net | 직업: 실내장식 디자이너
# 이름: 한순자 | 이메일: imiyeong@example.net | 직업: 경기심판 및 경기기록원
# 이름: 오윤서 | 이메일: simgyeongsug@example.net | 직업: 상/하수도 처리장치 조작원
# 이름: 김경자 | 이메일: seonghyeon14@example.net | 직업: 아나운서 및 리포터
# 이름: 한현숙 | 이메일: gimsugja@example.org | 직업: 물품이동 장비 조작원
# 이름: 박혜진 | 이메일: junhyeogcoe@example.org | 직업: 제화원
# 이름: 장성수 | 이메일: iseonghyeon@example.org | 직업: 감정평가 전문가
# 이름: 최정수 | 이메일: seoyeongi@example.org | 직업: 음식서비스관련 관리자
# 이름: 최현숙 | 이메일: jieun63@example.org | 직업: 사진인화 및 현상기 조작원
# 이름: 김영호 | 이메일: jimincoe@example.org | 직업: 농림어업관련 시험원
# 이름: 김예준 | 이메일: sunog18@example.org | 직업: 기타 판매 및 고객 서비스 관리자
# 이름: 박준서 | 이메일: nan@example.com | 직업: 섬유공학 기술자 및 연구원
# 이름: 문광수 | 이메일: qgim@example.com | 직업: 장례 상담원 및 장례 지도사
# 이름: 윤우진 | 이메일: eungyeonggim@example.com | 직업: 조명기사 및 영사기사
# 이름: 류명숙 | 이메일: yeonghyigim@example.org | 직업: 경영지원 관리자
# 이름: 박수진 | 이메일: junho82@example.com | 직업: 강구조물 가공원 및 건립원
# 이름: 장영수 | 이메일: heojeongja@example.net | 직업: 웨이터
# 이름: 구선영 | 이메일: iyeongil@example.net | 직업: 김치 및 밑반찬 제조 종사원
# 이름: 이현지 | 이메일: miyeong34@example.net | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 박지혜 | 이메일: yunmyeongsug@example.net | 직업: 정부 및 공공 행정 전문가
# 이름: 한지우 | 이메일: hson@example.org | 직업: 기타 공학관련 기술자 및 시험원
# 이름: 김아름 | 이메일: vi@example.com | 직업: 기타 사육관련 종사원
# 이름: 서주원 | 이메일: songeunju@example.com | 직업: 이용사
# 이름: 김명숙 | 이메일: myeongjayu@example.com | 직업: 기타 자동차 운전원
# 이름: 정미영 | 이메일: gimsangceol@example.net | 직업: 화학물 가공장치 조작원
# 이름: 이재호 | 이메일: eunyeongi@example.net | 직업: 제빵원 및 제과원
# 이름: 윤수진 | 이메일: seonghuni@example.org | 직업: 광원/채석원 및 석재 절단원
# 이름: 김성훈 | 이메일: fbag@example.net | 직업: 감정평가 전문가
# 이름: 김준영 | 이메일: sujin61@example.org | 직업: 한식 주방장 및 조리사
# 이름: 고아름 | 이메일: rgim@example.com | 직업: 주차 관리원 및 안내원
# 이름: 엄영희 | 이메일: seongmin37@example.com | 직업: 컴퓨터 하드웨어 기술자 및 연구원
# 이름: 홍민재 | 이메일: vgim@example.com | 직업: 기타 식품가공관련 종사원
# 이름: 안은경 | 이메일: ui@example.net | 직업: 가스/에너지 기술자 및 연구원
# 이름: 황영순 | 이메일: yeongmi84@example.net | 직업: 사진기자 및 사진가
# 이름: 김지민 | 이메일: gimdoyun@example.org | 직업: 중식 주방장 및 조리사
# 이름: 박예지 | 이메일: seohyeongwag@example.com | 직업: 패션 디자이너
# 이름: 손성수 | 이메일: wgim@example.com | 직업: 작가 및 관련 전문가
# 이름: 한지후 | 이메일: yeweon02@example.net | 직업: 점토제품 생산기 조작원
# 이름: 박영미 | 이메일: ijeongsu@example.org | 직업: 데이터베이스 개발자
# 이름: 심영미 | 이메일: yeonggilgim@example.org | 직업: 바텐더
# 이름: 구서현 | 이메일: seonghun96@example.net | 직업: 기타 식품가공관련 종사원
# 이름: 김승민 | 이메일: hyeonuhan@example.com | 직업: 사진기자 및 사진가
# 이름: 최도윤 | 이메일: ogim@example.org | 직업: 도금 및 금속분무기 조작원
# 이름: 김상호 | 이메일: baghyeonu@example.net | 직업: 기타 행정 및 경영지원 관리자
# 이름: 구영철 | 이메일: wjang@example.org | 직업: 컴퓨터시스템 설계 및 분석가
# 이름: 엄광수 | 이메일: jihuncoe@example.org | 직업: 석유 및 천연가스제조 관련 제어장치 조작원
# 이름: 김지은 | 이메일: bagyeongsu@example.org | 직업: 정보 시스템 운영자
# 이름: 차예진 | 이메일: fbag@example.net | 직업: 컴퓨터 보안 전문가
# 이름: 김정희 | 이메일: seominseo@example.net | 직업: 제관원
# 이름: 김경희 | 이메일: bagdohyeon@example.net | 직업: 낙농업관련 종사원
# 이름: 이현숙 | 이메일: minseogbag@example.com | 직업: 보험 심사원 및 사무원
# 이름: 박정자 | 이메일: jeonghun73@example.net | 직업: 영상/녹화 및 편집 기사
# 이름: 박영순 | 이메일: gseo@example.net | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 이민서 | 이메일: seosanghun@example.com | 직업: 법무사 및 집행관
# 이름: 김미정 | 이메일: jujiyeong@example.net | 직업: 피부미용 및 체형관리사
# 이름: 이영식 | 이메일: namyeongil@example.net | 직업: 애완동물 미용사
# 이름: 권정웅 | 이메일: bgim@example.com | 직업: 청원 경찰
# 이름: 류명자 | 이메일: ii@example.net | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 윤정수 | 이메일: ijinho@example.com | 직업: 보험 심사원 및 사무원
# 이름: 장예원 | 이메일: zseo@example.net | 직업: 컴퓨터시스템 설계 및 분석가
# 이름: 김미숙 | 이메일: zhan@example.com | 직업: 생산 및 품질 관리 사무원
# 이름: 서현숙 | 이메일: bjang@example.org | 직업: 광석 및 석제품 가공기 조작원
# 이름: 황옥순 | 이메일: eunjumun@example.org | 직업: 펄프 및 종이 제조장치 조작원
# 이름: 박채원 | 이메일: seongmin23@example.org | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 김영일 | 이메일: gimgyeongsu@example.org | 직업: 택시 운전원
# 이름: 김영진 | 이메일: sanghoi@example.org | 직업: 세탁원 및 다림질원
# 이름: 강서연 | 이메일: igim@example.com | 직업: 기타 비금속제품관련 생산기 조작원
# 이름: 심은영 | 이메일: gimyeongceol@example.org | 직업: 컴퓨터 보안 전문가
# 이름: 김지원 | 이메일: gimjunho@example.org | 직업: 항공기 정비원
# 이름: 이은영 | 이메일: jiweonhan@example.org | 직업: 경리 사무원
# 이름: 신하윤 | 이메일: seungmingo@example.org | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 김상철 | 이메일: mi@example.org | 직업: 노점 및 이동 판매원
# 이름: 김민준 | 이메일: jeonghunryu@example.net | 직업: 주유원
# 이름: 김영식 | 이메일: gimdohyeon@example.org | 직업: 인문과학 연구원
# 이름: 차혜진 | 이메일: gomyeongsug@example.net | 직업: 용접기 조작원
# 이름: 김미정 | 이메일: kgim@example.com | 직업: 건설 및 광업기계 설치 및 정비원
# 이름: 박지영 | 이메일: yeonggil57@example.org | 직업: 가사 도우미
# 이름: 김순옥 | 이메일: gimyeongil@example.net | 직업: 용접원
# 이름: 김영미 | 이메일: hanhaeun@example.org | 직업: 경기심판 및 경기기록원
# 이름: 이현주 | 이메일: bagmyeongsug@example.net | 직업: 부동산 컨설턴트 및 중개인
# 이름: 박도현 | 이메일: jeongsungim@example.com | 직업: 무용가 및 안무가
# 이름: 이준호 | 이메일: jiyeon54@example.net | 직업: 표백 및 염색 관련 조작원
# 이름: 박하윤 | 이메일: jieun81@example.net | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 유지현 | 이메일: iyeongil@example.com | 직업: 캐드원
# 이름: 백민준 | 이메일: san@example.org | 직업: 정보통신관련 관리자
# 이름: 전동현 | 이메일: subini@example.com | 직업: 양식원
# 이름: 신하윤 | 이메일: sgim@example.com | 직업: 가축 사육 종사원
# 이름: 고병철 | 이메일: gimjeongsun@example.org | 직업: 기타 목재 및 종이 관련 기계조작원
# 이름: 최진호 | 이메일: qgim@example.com | 직업: 투자 및 신용 분석가
# 이름: 이영수 | 이메일: ci@example.com | 직업: 가구 제조 및 수리원
# 이름: 이옥자 | 이메일: baesugja@example.org | 직업: 주유원
# 이름: 강명숙 | 이메일: nha@example.net | 직업: 기자 및 논설위원
# 이름: 최아름 | 이메일: jgwag@example.org | 직업: 인사 및 노사 관련 전문가
# 이름: 윤서연 | 이메일: eunjii@example.net | 직업: 승강기 설치 및 정비원
# 이름: 윤순옥 | 이메일: ogja76@example.org | 직업: 금속 / 재료공학 시험원
# 이름: 김영자 | 이메일: myeongsuggim@example.com | 직업: 제관기 조작원
# 이름: 박시우 | 이메일: gimjiyeon@example.com | 직업: 경비원
# 이름: 이미영 | 이메일: wbag@example.org | 직업: 금속기계부품 조립원
# 이름: 이정순 | 이메일: ki@example.com | 직업: 기타 사회복지관련 종사원
# 이름: 이성호 | 이메일: cryu@example.net | 직업: 가축 사육 종사원
# 이름: 윤정수 | 이메일: bageunseo@example.net | 직업: 조림/영림 및 벌목원
# 이름: 문서연 | 이메일: jeongho47@example.org | 직업: 육류/어패류 및 낙농품 가공 기계조작원
# 이름: 박영환 | 이메일: pgo@example.net | 직업: 법률관련 사무원
# 이름: 문성훈 | 이메일: coehyeonju@example.net | 직업: 국악 및 전통예능인
# 이름: 배명자 | 이메일: yeongilbag@example.org | 직업: 위생사
# 이름: 박하은 | 이메일: seoyeong30@example.net | 직업: 광원/채석원 및 석재 절단원
# 이름: 이정식 | 이메일: sgim@example.org | 직업: 청소원
# 이름: 문은주 | 이메일: ssim@example.com | 직업: 환경공학 기술자 및 연구원
# 이름: 김재호 | 이메일: egim@example.net | 직업: 산업안전 및 위험 관리원
# 이름: 오정자 | 이메일: seongsu21@example.org | 직업: 작가 및 관련 전문가
# 이름: 강진우 | 이메일: lbag@example.net | 직업: 통신공학 기술자 및 연구원
# 이름: 황민재 | 이메일: zi@example.net | 직업: 건축 석공
# 이름: 박종수 | 이메일: sanghunson@example.org | 직업: 인사 및 교육/훈련 사무원
# 이름: 박준영 | 이메일: seongsusong@example.com | 직업: 산업전공
# 이름: 이동현 | 이메일: ii@example.net | 직업: 화학공학 기술자 및 연구원
# 이름: 권춘자 | 이메일: eunjii@example.net | 직업: 과수작물 재배원
# 이름: 김영희 | 이메일: shong@example.net | 직업: 간병인
# 이름: 이미영 | 이메일: seojungang@example.net | 직업: 감정평가 전문가
# 이름: 박서영 | 이메일: fim@example.com | 직업: 패턴사
# 이름: 김경자 | 이메일: yunseo04@example.net | 직업: 단열공
# 이름: 조은서 | 이메일: baegyeongja@example.com | 직업: 유리제조 및 가공기 조작원
# 이름: 주보람 | 이메일: fgwag@example.org | 직업: 컴퓨터 보안 전문가
# 이름: 박예지 | 이메일: seongjingim@example.net | 직업: 생명과학 연구원
# 이름: 배진우 | 이메일: jeonghungim@example.org | 직업: 구두 미화원
# 이름: 이성민 | 이메일: sangceol13@example.net | 직업: 캐드원
# 이름: 최준호 | 이메일: tgim@example.net | 직업: 유리제조 및 가공기 조작원
# 이름: 김채원 | 이메일: bagyeonggil@example.net | 직업: 건축가 및 건축공학 기술자
# 이름: 권유진 | 이메일: scoe@example.org | 직업: 생명과학 시험원
# 이름: 이성훈 | 이메일: seonghunseo@example.org | 직업: 영상/녹화 및 편집 기사
# 이름: 김정희 | 이메일: jiweon13@example.org | 직업: 목재 가공관련 기계 조작원
# 이름: 배예지 | 이메일: jihugim@example.com | 직업: 번역가
# 이름: 신은정 | 이메일: jeongsug34@example.net | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 김경숙 | 이메일: yeongsig84@example.org | 직업: 제품 디자이너
# 이름: 우현주 | 이메일: jihu98@example.net | 직업: 관세행정 사무원
# 이름: 김은영 | 이메일: seongjinbag@example.org | 직업: 예능 강사
# 이름: 박민재 | 이메일: jieun39@example.com | 직업: 한식 주방장 및 조리사
# 이름: 윤지현 | 이메일: ggim@example.org | 직업: 도금 및 금속분무기 조작원
# 이름: 이숙자 | 이메일: noseoyeon@example.com | 직업: 주차 관리원 및 안내원
# 이름: 이보람 | 이메일: hsong@example.org | 직업: 기타 기능관련 종사원
# 이름: 박영미 | 이메일: gyeonghyi92@example.org | 직업: 기타 배관공
# 이름: 박주원 | 이메일: ijeongsu@example.com | 직업: 정부행정 관리자
# 이름: 김수진 | 이메일: qyun@example.org | 직업: 기타 스포츠 및 레크레이션 관련 전문가
# 이름: 송정남 | 이메일: yejinim@example.com | 직업: 손해사정인
# 이름: 이정식 | 이메일: seonghunheo@example.org | 직업: 혼례 종사원
# 이름: 최우진 | 이메일: minseogan@example.net | 직업: 실내장식 디자이너
# 이름: 김현지 | 이메일: ihyeonu@example.net | 직업: 기타 사육관련 종사원
# 이름: 고예준 | 이메일: ugim@example.net | 직업: 경리 사무원
# 이름: 김영철 | 이메일: minseog09@example.net | 직업: 인쇄기 조작원
# 이름: 민영식 | 이메일: isangceol@example.com | 직업: 병무행정 사무원
# 이름: 김현우 | 이메일: yangmisug@example.org | 직업: 경량 철골공
# 이름: 오순옥 | 이메일: han@example.net | 직업: 여행 및 관광통역 안내원
# 이름: 송재현 | 이메일: fheo@example.com | 직업: 기타 배달원
# 이름: 김영숙 | 이메일: eunju96@example.net | 직업: 단조기 조작원
# 이름: 박진우 | 이메일: sonseungmin@example.com | 직업: 기타 건설관련 기능 종사원
# 이름: 류예준 | 이메일: cgim@example.com | 직업: 재단사
# 이름: 송지우 | 이메일: hyeonju42@example.com | 직업: 임상병리사
# 이름: 강상철 | 이메일: jihu63@example.org | 직업: 기타 석유 및 화학물 가공장치 조작원
# 이름: 박예준 | 이메일: ri@example.net | 직업: 기타 문리/기술 및 예능 강사
# 이름: 김정호 | 이메일: seunghyeon84@example.net | 직업: 건축 목공
# 이름: 오경희 | 이메일: ci@example.org | 직업: 악기제조 및 조율사
# 이름: 박정희 | 이메일: xyun@example.net | 직업: 변호사
# 이름: 이옥자 | 이메일: eseo@example.net | 직업: 고무 및 플라스틱 제품 조립원
# 이름: 이영진 | 이메일: yunmijeong@example.org | 직업: 운송 사무원
# 이름: 최지후 | 이메일: seodoyun@example.com | 직업: 전자공학 기술자 및 연구원
# 이름: 김종수 | 이메일: gimbyeongceol@example.net | 직업: 네트워크시스템 개발자
# 이름: 이상철 | 이메일: miyeongi@example.org | 직업: 판금원
# 이름: 최하윤 | 이메일: jiyeong56@example.net | 직업: 고객 상담 및 모니터 요원
# 이름: 이지원 | 이메일: gimjiyeong@example.net | 직업: 양장 및 양복 제조원
# 이름: 김영희 | 이메일: yi@example.org | 직업: 과실 및 채소 관련 기계조작원
# 이름: 박은주 | 이메일: yunseunghyeon@example.net | 직업: 기타 서비스관련 단순 종사원
# 이름: 김민수 | 이메일: namgyeongsug@example.com | 직업: 기타 섬유 및 가죽 관련 기능 종사원
# 이름: 신지훈 | 이메일: jiweon88@example.com | 직업: 건축 도장공
# 이름: 송지영 | 이메일: yeongsiggim@example.org | 직업: 인문과학 연구원
# 이름: 이도윤 | 이메일: doyunhong@example.com | 직업: 회계사
# 이름: 이영수 | 이메일: gyeongsu42@example.net | 직업: 법률/경찰/소방 및 교도 관리자
# 이름: 홍명자 | 이메일: ryujaehyeon@example.org | 직업: 통계관련 사무원
# 이름: 박도현 | 이메일: lnam@example.com | 직업: 정보통신관련 관리자
# 이름: 류미숙 | 이메일: yeonghwan70@example.com | 직업: 도장기 조작원
# 이름: 김현우 | 이메일: yeweon27@example.com | 직업: 기타 여가 및 스포츠 관련 종사원
# 이름: 박수민 | 이메일: ieunji@example.com | 직업: 건설 및 광업 관련 관리자
# 이름: 이성현 | 이메일: oyun@example.net | 직업: 배관 세정원 및 방역원
# 이름: 양은정 | 이메일: simmigyeong@example.org | 직업: 금속가공관련 제어장치 조작원
# 이름: 조병철 | 이메일: jeongsuni@example.org | 직업: 조세행정 사무원
# 이름: 이지원 | 이메일: nbaeg@example.net | 직업: 의지보조기기사
# 이름: 김승현 | 이메일: jeonghogim@example.com | 직업: 섬유제조 기계조작원
# 이름: 안지원 | 이메일: jiminbag@example.org | 직업: 기타 전문서비스 관리자
# 이름: 최승민 | 이메일: bagjiyeong@example.org | 직업: 기자 및 논설위원
# 이름: 손혜진 | 이메일: yeongmi74@example.org | 직업: 기술 영업원
# 이름: 김명자 | 이메일: agim@example.org | 직업: 섀시 조립 및 설치원
# 이름: 김민재 | 이메일: seongjihye@example.org | 직업: 음식 배달원
# 이름: 주경희 | 이메일: sumin39@example.net | 직업: 주차 관리원 및 안내원
# 이름: 이지은 | 이메일: minsugwag@example.net | 직업: 통신 및 방송송출 장비 기사
# 이름: 김은정 | 이메일: hbag@example.org | 직업: 출판물 전문가
# 이름: 박순자 | 이메일: theo@example.net | 직업: 판금원
# 이름: 김지은 | 이메일: bgim@example.com | 직업: 공업기계 설치 및 정비원
# 이름: 김아름 | 이메일: yeongsig25@example.org | 직업: 육아 도우미
# 이름: 이지후 | 이메일: bageungyeong@example.org | 직업: 화물차 및 특수차 운전원
# 이름: 김보람 | 이메일: omin@example.net | 직업: 기타 제조관련 기계 조작원
# 이름: 최진호 | 이메일: qcoe@example.org | 직업: 한복 제조원
# 이름: 김지현 | 이메일: gwangsuseo@example.com | 직업: 캐드원
# 이름: 이미숙 | 이메일: myeongjai@example.org | 직업: 임상병리사
# 이름: 양경희 | 이메일: rson@example.net | 직업: 건설자재 시험원
# 이름: 윤영순 | 이메일: icunja@example.org | 직업: 고무 및 플라스틱 제품 조립원
# 이름: 권성민 | 이메일: hgim@example.com | 직업: 상점 판매원
# 이름: 김성호 | 이메일: ebag@example.com | 직업: 정보 시스템 운영자
# 이름: 김지혜 | 이메일: jeongho87@example.com | 직업: 연예인 및 스포츠 매니저
# 이름: 김지아 | 이메일: seoyeon57@example.com | 직업: 정보통신관련 관리자
# 이름: 성민지 | 이메일: gimgyeongsu@example.com | 직업: 이용사
# 이름: 구준서 | 이메일: gyeongsu78@example.com | 직업: 장기 부사관 및 준위
# 이름: 안영진 | 이메일: yeongil86@example.org | 직업: 기타 배달원
# 이름: 강광수 | 이메일: wgim@example.com | 직업: 신용 추심원
# 이름: 김성훈 | 이메일: gimminjae@example.com | 직업: 영양사
# 이름: 최지연 | 이메일: qi@example.org | 직업: 종이제품 생산기 조작원
# 이름: 이아름 | 이메일: jaehogang@example.org | 직업: 기타 스포츠 및 레크레이션 관련 전문가

# %%
class User:
    def __init__(self, name):
        # HAS (Attributes)
        self.name = name
        self.following = None  # 내가 쫓고 있는 대상
        self.follower = None   # 나를 쫓고 있는 대상

    # DOES (Method)
    def following_mode(self, target):
        """상대방을 쫓는 모드 활성화 및 속성 변경"""
        self.following = target.name
        target.follower = self.name

        print(f"[{self.name}]이(가) [{target.name}]을(를) 추격하기 시작합니다!")
        print(f"상태 확인 -> Tom의 타겟: {self.following}, Jerry의 추격자: {target.follower}")
        print("-" * 30)

        # 10번 반복 수행
        for i in range(1, 11):
            print(f"{i}회차: 🏃 {self.name}이(가) {target.name}을(를) 열심히 쫓아가는 중...")

        print("-" * 30)
        print(f"추격 종료: {self.name}은(는) 지쳤습니다.")

# 객체 생성
tom = User("Tom")
jerry = User("Jerry")

# Tom이 Jerry를 10번 쫓아가는 행위 실행
tom.following_mode(jerry)
# Out:
# [Tom]이(가) [Jerry]을(를) 추격하기 시작합니다!
# 상태 확인 -> Tom의 타겟: Jerry, Jerry의 추격자: Tom
# ------------------------------
# 1회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 2회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 3회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 4회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 5회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 6회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 7회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 8회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 9회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# 10회차: 🏃 Tom이(가) Jerry을(를) 열심히 쫓아가는 중...
# ------------------------------
# 추격 종료: Tom은(는) 지쳤습니다.
